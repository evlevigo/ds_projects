# %% [markdown]
# # Оптимизация управления персоналом компании "Работа с заботой"
#
# **Описание проекта**
#
# HR-аналитики компании «Работа с заботой» помогают бизнесу
# оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают,
# как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится
# машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы
# бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них —
# уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм
# обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля
# их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью
# удовлетворён.
#
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо
# сначала оповестить об опросе, а затем проследить, что все его прошли.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Цели-и-задачи-проекта" data-toc-modified-id="Цели-и-задачи-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Цели и задачи проекта</a></span></li><li><span><a href="#Импорт-библиотек,-загрузка-данных,-константы" data-toc-modified-id="Импорт-библиотек,-загрузка-данных,-константы-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Импорт библиотек, загрузка данных, константы</a></span></li><li><span><a href="#Функции,-используемые-в-проекте" data-toc-modified-id="Функции,-используемые-в-проекте-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Функции, используемые в проекте</a></span><ul class="toc-item"><li><span><a href="#nice_t---Функция-форматирования-таблиц" data-toc-modified-id="nice_t---Функция-форматирования-таблиц-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>nice_t - Функция форматирования таблиц</a></span></li><li><span><a href="#data_info---Функция-вывода-информации-о-датафрейме" data-toc-modified-id="data_info---Функция-вывода-информации-о-датафрейме-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>data_info - Функция вывода информации о датафрейме</a></span></li><li><span><a href="#data_category_analyze---Функция-вывода-круговых-диаграмм-категориальных-данных" data-toc-modified-id="data_category_analyze---Функция-вывода-круговых-диаграмм-категориальных-данных-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>data_category_analyze - Функция вывода круговых диаграмм категориальных данных</a></span></li><li><span><a href="#data_numbers_analyze---Функция-анализа-числовых-данных" data-toc-modified-id="data_numbers_analyze---Функция-анализа-числовых-данных-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>data_numbers_analyze - Функция анализа числовых данных</a></span></li><li><span><a href="#data_hist_analyze---Функция-вывода-гистограммы-распределения-числовых-значений" data-toc-modified-id="data_hist_analyze---Функция-вывода-гистограммы-распределения-числовых-значений-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>data_hist_analyze - Функция вывода гистограммы распределения числовых значений</a></span></li><li><span><a href="#find_mode---Функция-нахождения-моды-с-определенными-условиями" data-toc-modified-id="find_mode---Функция-нахождения-моды-с-определенными-условиями-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>find_mode - Функция нахождения моды с определенными условиями</a></span></li><li><span><a href="#find_duplicates---Функция-нахождения-явных-дубликатов-в-списке-датафреймов" data-toc-modified-id="find_duplicates---Функция-нахождения-явных-дубликатов-в-списке-датафреймов-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>find_duplicates - Функция нахождения явных дубликатов в списке датафреймов</a></span></li><li><span><a href="#find_nans---Функция-нахождения-пропусков-в-списке-датафреймов" data-toc-modified-id="find_nans---Функция-нахождения-пропусков-в-списке-датафреймов-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>find_nans - Функция нахождения пропусков в списке датафреймов</a></span></li><li><span><a href="#hist_comparison---Функция-построения-плотности-распределения-тренировочной-и-тестовой-выборок" data-toc-modified-id="hist_comparison---Функция-построения-плотности-распределения-тренировочной-и-тестовой-выборок-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>hist_comparison - Функция построения плотности распределения тренировочной и тестовой выборок</a></span></li><li><span><a href="#smape_calc---Функция-вычисления-метрики-SMAPE" data-toc-modified-id="smape_calc---Функция-вычисления-метрики-SMAPE-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>smape_calc - Функция вычисления метрики SMAPE</a></span></li><li><span><a href="#IQR_cat_make---Функция-преобразования-числовых--данных-в-категориальные" data-toc-modified-id="IQR_cat_make---Функция-преобразования-числовых--данных-в-категориальные-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>IQR_cat_make - Функция преобразования числовых  данных в категориальные</a></span></li></ul></li><li><span><a href="#Цель-№1:-Построить-модель,-которая-сможет-предсказать-уровень-удовлетворённости-сотрудника-на-основе-данных-заказчика." data-toc-modified-id="Цель-№1:-Построить-модель,-которая-сможет-предсказать-уровень-удовлетворённости-сотрудника-на-основе-данных-заказчика.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Цель №1: Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.</a></span><ul class="toc-item"><li><span><a href="#Общая-информация-о-данных" data-toc-modified-id="Общая-информация-о-данных-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Общая информация о данных</a></span><ul class="toc-item"><li><span><a href="#Описание-данных-train_job_satisfaction_rate.csv" data-toc-modified-id="Описание-данных-train_job_satisfaction_rate.csv-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Описание данных train_job_satisfaction_rate.csv</a></span></li><li><span><a href="#Общие-сведения-train_job_satisfaction_rate.csv" data-toc-modified-id="Общие-сведения-train_job_satisfaction_rate.csv-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Общие сведения train_job_satisfaction_rate.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.1.2.1"><span class="toc-item-num">4.1.2.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Описание-данных-test_features.csv" data-toc-modified-id="Описание-данных-test_features.csv-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Описание данных test_features.csv</a></span></li><li><span><a href="#Общие-сведения-test_features.csv" data-toc-modified-id="Общие-сведения-test_features.csv-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Общие сведения test_features.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.1.4.1"><span class="toc-item-num">4.1.4.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Описание-данных-test_target_job_satisfaction_rate.csv" data-toc-modified-id="Описание-данных-test_target_job_satisfaction_rate.csv-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Описание данных test_target_job_satisfaction_rate.csv</a></span></li><li><span><a href="#Общие-сведения-test_target_job_satisfaction_rate.csv" data-toc-modified-id="Общие-сведения-test_target_job_satisfaction_rate.csv-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Общие сведения test_target_job_satisfaction_rate.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.1.6.1"><span class="toc-item-num">4.1.6.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-наименований-столбцов" data-toc-modified-id="Замена-наименований-столбцов-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Замена наименований столбцов</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.2.1.1"><span class="toc-item-num">4.2.1.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Преобразование-типов-данных" data-toc-modified-id="Преобразование-типов-данных-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Преобразование типов данных</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.2.2.1"><span class="toc-item-num">4.2.2.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Обработка-явных-дубликатов" data-toc-modified-id="Обработка-явных-дубликатов-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Обработка явных дубликатов</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.2.3.1"><span class="toc-item-num">4.2.3.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Обработка-неявных-дубликатов,-опечаток,-ошибок,-аномальных-значений-строковых-данных" data-toc-modified-id="Обработка-неявных-дубликатов,-опечаток,-ошибок,-аномальных-значений-строковых-данных-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Обработка неявных дубликатов, опечаток, ошибок, аномальных значений строковых данных</a></span><ul class="toc-item"><li><span><a href="#train_job_satisfaction_rate.csv" data-toc-modified-id="train_job_satisfaction_rate.csv-4.2.4.1"><span class="toc-item-num">4.2.4.1&nbsp;&nbsp;</span>train_job_satisfaction_rate.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.2.4.1.1"><span class="toc-item-num">4.2.4.1.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#test_features.csv" data-toc-modified-id="test_features.csv-4.2.4.2"><span class="toc-item-num">4.2.4.2&nbsp;&nbsp;</span>test_features.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.2.4.2.1"><span class="toc-item-num">4.2.4.2.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#test_target_job_satisfaction_rate.csv" data-toc-modified-id="test_target_job_satisfaction_rate.csv-4.2.4.3"><span class="toc-item-num">4.2.4.3&nbsp;&nbsp;</span>test_target_job_satisfaction_rate.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.2.4.3.1"><span class="toc-item-num">4.2.4.3.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li></ul></li><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Выводы раздела</a></span></li><li><span><a href="#Обработка-пропущенных-значений" data-toc-modified-id="Обработка-пропущенных-значений-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Обработка пропущенных значений</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропущенных-значений-train_job_satisfaction_rate.csv" data-toc-modified-id="Обработка-пропущенных-значений-train_job_satisfaction_rate.csv-4.2.6.1"><span class="toc-item-num">4.2.6.1&nbsp;&nbsp;</span>Обработка пропущенных значений train_job_satisfaction_rate.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.2.6.1.1"><span class="toc-item-num">4.2.6.1.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#Обработка-пропущенных-значений-test_features.csv" data-toc-modified-id="Обработка-пропущенных-значений-test_features.csv-4.2.6.2"><span class="toc-item-num">4.2.6.2&nbsp;&nbsp;</span>Обработка пропущенных значений test_features.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.2.6.2.1"><span class="toc-item-num">4.2.6.2.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#Обработка-пропущенных-значений-test_target_job_satisfaction_rate.csv" data-toc-modified-id="Обработка-пропущенных-значений-test_target_job_satisfaction_rate.csv-4.2.6.3"><span class="toc-item-num">4.2.6.3&nbsp;&nbsp;</span>Обработка пропущенных значений test_target_job_satisfaction_rate.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.2.6.3.1"><span class="toc-item-num">4.2.6.3.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.2.6.4"><span class="toc-item-num">4.2.6.4&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Предварительная-обработка-аномальных-значений" data-toc-modified-id="Предварительная-обработка-аномальных-значений-4.2.7"><span class="toc-item-num">4.2.7&nbsp;&nbsp;</span>Предварительная обработка аномальных значений</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-4.2.7.1"><span class="toc-item-num">4.2.7.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-4.2.8"><span class="toc-item-num">4.2.8&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Подраздел-исключен-из-исследования-ввиду-невозможности-реализации-показателей-метрики" data-toc-modified-id="Подраздел-исключен-из-исследования-ввиду-невозможности-реализации-показателей-метрики-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Подраздел исключен из исследования ввиду невозможности реализации показателей метрики</a></span></li><li><span><a href="#train_job_satisfaction_rate.csv" data-toc-modified-id="train_job_satisfaction_rate.csv-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>train_job_satisfaction_rate.csv</a></span><ul class="toc-item"><li><span><a href="#Категориальные-данные" data-toc-modified-id="Категориальные-данные-4.3.2.1"><span class="toc-item-num">4.3.2.1&nbsp;&nbsp;</span>Категориальные данные</a></span></li><li><span><a href="#Количественные-данные" data-toc-modified-id="Количественные-данные-4.3.2.2"><span class="toc-item-num">4.3.2.2&nbsp;&nbsp;</span>Количественные данные</a></span></li><li><span><a href="#Распределение-количественных-данных" data-toc-modified-id="Распределение-количественных-данных-4.3.2.3"><span class="toc-item-num">4.3.2.3&nbsp;&nbsp;</span>Распределение количественных данных</a></span></li><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.3.2.4"><span class="toc-item-num">4.3.2.4&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#test_features.csv" data-toc-modified-id="test_features.csv-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>test_features.csv</a></span><ul class="toc-item"><li><span><a href="#Категориальные-данные" data-toc-modified-id="Категориальные-данные-4.3.3.1"><span class="toc-item-num">4.3.3.1&nbsp;&nbsp;</span>Категориальные данные</a></span></li><li><span><a href="#Количественные-данные" data-toc-modified-id="Количественные-данные-4.3.3.2"><span class="toc-item-num">4.3.3.2&nbsp;&nbsp;</span>Количественные данные</a></span></li><li><span><a href="#Распределение-количественных-данных" data-toc-modified-id="Распределение-количественных-данных-4.3.3.3"><span class="toc-item-num">4.3.3.3&nbsp;&nbsp;</span>Распределение количественных данных</a></span></li><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.3.3.4"><span class="toc-item-num">4.3.3.4&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#test_target_job_satisfaction_rate.csv" data-toc-modified-id="test_target_job_satisfaction_rate.csv-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>test_target_job_satisfaction_rate.csv</a></span><ul class="toc-item"><li><span><a href="#Количественные-данные" data-toc-modified-id="Количественные-данные-4.3.4.1"><span class="toc-item-num">4.3.4.1&nbsp;&nbsp;</span>Количественные данные</a></span></li><li><span><a href="#Распределение-количественных-данных" data-toc-modified-id="Распределение-количественных-данных-4.3.4.2"><span class="toc-item-num">4.3.4.2&nbsp;&nbsp;</span>Распределение количественных данных</a></span></li><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.3.4.3"><span class="toc-item-num">4.3.4.3&nbsp;&nbsp;</span>Выводы подраздела</a></span></li><li><span><a href="#Распределение-тренировочной-и-тестовой-выборок" data-toc-modified-id="Распределение-тренировочной-и-тестовой-выборок-4.3.4.4"><span class="toc-item-num">4.3.4.4&nbsp;&nbsp;</span>Распределение тренировочной и тестовой выборок</a></span></li><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-4.3.4.5"><span class="toc-item-num">4.3.4.5&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Корреляционный-анализ-признаков" data-toc-modified-id="Корреляционный-анализ-признаков-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Корреляционный анализ признаков</a></span><ul class="toc-item"><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li></ul></li><li><span><a href="#Промежуточный-вывод-(Цель-№1)" data-toc-modified-id="Промежуточный-вывод-(Цель-№1)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Промежуточный вывод (Цель №1)</a></span></li><li><span><a href="#Цель-№2:-Предсказание-увольнения-сотрудника-из-компании" data-toc-modified-id="Цель-№2:-Предсказание-увольнения-сотрудника-из-компании-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Цель №2: Предсказание увольнения сотрудника из компании</a></span><ul class="toc-item"><li><span><a href="#Общая-информация-о-данных" data-toc-modified-id="Общая-информация-о-данных-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Общая информация о данных</a></span><ul class="toc-item"><li><span><a href="#Описание-данных-train_quit.csv" data-toc-modified-id="Описание-данных-train_quit.csv-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Описание данных train_quit.csv</a></span></li><li><span><a href="#Общие-сведения-train_quit.csv" data-toc-modified-id="Общие-сведения-train_quit.csv-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Общие сведения train_quit.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-6.1.2.1"><span class="toc-item-num">6.1.2.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Описание-данных-test_features.csv" data-toc-modified-id="Описание-данных-test_features.csv-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Описание данных test_features.csv</a></span></li><li><span><a href="#Описание-данных-test_target_quit.csv" data-toc-modified-id="Описание-данных-test_target_quit.csv-6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span>Описание данных test_target_quit.csv</a></span></li><li><span><a href="#Общие-сведения-test_target_quit.csv" data-toc-modified-id="Общие-сведения-test_target_quit.csv-6.1.5"><span class="toc-item-num">6.1.5&nbsp;&nbsp;</span>Общие сведения test_target_quit.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-6.1.5.1"><span class="toc-item-num">6.1.5.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-6.1.6"><span class="toc-item-num">6.1.6&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-наименований-столбцов" data-toc-modified-id="Замена-наименований-столбцов-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Замена наименований столбцов</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-6.2.1.1"><span class="toc-item-num">6.2.1.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Обработка-пропущенных-значений" data-toc-modified-id="Обработка-пропущенных-значений-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Обработка пропущенных значений</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-6.2.2.1"><span class="toc-item-num">6.2.2.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Преобразование-типов-данных" data-toc-modified-id="Преобразование-типов-данных-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Преобразование типов данных</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-6.2.3.1"><span class="toc-item-num">6.2.3.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Обработка-явных-дубликатов" data-toc-modified-id="Обработка-явных-дубликатов-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Обработка явных дубликатов</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-6.2.4.1"><span class="toc-item-num">6.2.4.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Обработка-неявных-дубликатов" data-toc-modified-id="Обработка-неявных-дубликатов-6.2.5"><span class="toc-item-num">6.2.5&nbsp;&nbsp;</span>Обработка неявных дубликатов</a></span><ul class="toc-item"><li><span><a href="#train_quit.csv" data-toc-modified-id="train_quit.csv-6.2.5.1"><span class="toc-item-num">6.2.5.1&nbsp;&nbsp;</span>train_quit.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.2.5.1.1"><span class="toc-item-num">6.2.5.1.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#test_features.csv" data-toc-modified-id="test_features.csv-6.2.5.2"><span class="toc-item-num">6.2.5.2&nbsp;&nbsp;</span>test_features.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.2.5.2.1"><span class="toc-item-num">6.2.5.2.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#test_target_quit.csv" data-toc-modified-id="test_target_quit.csv-6.2.5.3"><span class="toc-item-num">6.2.5.3&nbsp;&nbsp;</span>test_target_quit.csv</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.2.5.3.1"><span class="toc-item-num">6.2.5.3.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-6.2.5.4"><span class="toc-item-num">6.2.5.4&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Предварительная-обработка-аномальных-значений" data-toc-modified-id="Предварительная-обработка-аномальных-значений-6.2.6"><span class="toc-item-num">6.2.6&nbsp;&nbsp;</span>Предварительная обработка аномальных значений</a></span><ul class="toc-item"><li><span><a href="#Выводы-раздела" data-toc-modified-id="Выводы-раздела-6.2.6.1"><span class="toc-item-num">6.2.6.1&nbsp;&nbsp;</span>Выводы раздела</a></span></li></ul></li><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-6.2.7"><span class="toc-item-num">6.2.7&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#train_quit.csv" data-toc-modified-id="train_quit.csv-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>train_quit.csv</a></span><ul class="toc-item"><li><span><a href="#Количественные-данные" data-toc-modified-id="Количественные-данные-6.3.1.1"><span class="toc-item-num">6.3.1.1&nbsp;&nbsp;</span>Количественные данные</a></span></li><li><span><a href="#Распределение-количественных-данных" data-toc-modified-id="Распределение-количественных-данных-6.3.1.2"><span class="toc-item-num">6.3.1.2&nbsp;&nbsp;</span>Распределение количественных данных</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.3.1.2.1"><span class="toc-item-num">6.3.1.2.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li></ul></li><li><span><a href="#test_features.csv" data-toc-modified-id="test_features.csv-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>test_features.csv</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.3.2.0.1"><span class="toc-item-num">6.3.2.0.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li></ul></li><li><span><a href="#test_target_quit.csv" data-toc-modified-id="test_target_quit.csv-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>test_target_quit.csv</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.3.3.0.1"><span class="toc-item-num">6.3.3.0.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#Распределение-тренировочной-и-тестовой-выборок" data-toc-modified-id="Распределение-тренировочной-и-тестовой-выборок-6.3.3.1"><span class="toc-item-num">6.3.3.1&nbsp;&nbsp;</span>Распределение тренировочной и тестовой выборок</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.3.3.1.1"><span class="toc-item-num">6.3.3.1.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#Портрет-уволившегося-сотрудника" data-toc-modified-id="Портрет-уволившегося-сотрудника-6.3.3.2"><span class="toc-item-num">6.3.3.2&nbsp;&nbsp;</span>Портрет уволившегося сотрудника</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.3.3.2.1"><span class="toc-item-num">6.3.3.2.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li><li><span><a href="#Распределения-признака-job_satisfaction_rate-для-ушедших-и-оставшихся-сотрудников." data-toc-modified-id="Распределения-признака-job_satisfaction_rate-для-ушедших-и-оставшихся-сотрудников.-6.3.3.3"><span class="toc-item-num">6.3.3.3&nbsp;&nbsp;</span>Распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников.</a></span><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.3.3.3.1"><span class="toc-item-num">6.3.3.3.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li></ul></li><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Добавление-нового-входного-признака" data-toc-modified-id="Добавление-нового-входного-признака-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Добавление нового входного признака</a></span><ul class="toc-item"><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Корреляционный-анализ-признаков" data-toc-modified-id="Корреляционный-анализ-признаков-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Корреляционный анализ признаков</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Выводы-подраздела" data-toc-modified-id="Выводы-подраздела-6.5.0.0.1"><span class="toc-item-num">6.5.0.0.1&nbsp;&nbsp;</span>Выводы подраздела</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Выводы-главы" data-toc-modified-id="Выводы-главы-6.7.1"><span class="toc-item-num">6.7.1&nbsp;&nbsp;</span>Выводы главы</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ## Цели и задачи проекта
#
# [К оглавлению](#Оглавление)
#
# В рамках работы над проектом должны быть достигнуты следующие цели:
# 1. Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
#     - Примечание заказчика: "почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник."
#
# 2. Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# Для достижения целей проекта должны быть выполнены следующие задачи:
#
# **Цель №1: Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.**
#
# 1. Исследовать общую информация о датафреймах
#     - Тренировочная выборка: `train_job_satisfaction_rate.csv`
#     - Входные признаки тестовой выборки: `test_features.csv`
#     - Целевой признак тестовой выборки: `test_target_job_satisfaction_rate.csv`
# 2. Выполнить предобработку данных:
#     - Обработка пропущенных значений
#     - Обработка неявных дубликатов
#     - Обработка явных дубликатов
#     - Изменение типов данных
#     - Выявление и обработка аномальных значений
# 3. Выполнить исследовательский и статистический анализ данных
#     - Исследовать все признаки и сделать выводы о том, как их нужно подготовить.
# 4. Подготовка данных для модели
#     - Подготовку признаков выполните в пайплайне, дополнив пайплайн шага предобработки. При кодировании учитывайте особенности признаков и моделей и используйте как минимум два кодировщика.
# 5. Обучить модели
#     - Обучить как минимум две модели. Возьмите одну линейную модель, а в качестве второй — дерево решений. Подберите гиперпараметры как минимум для одной модели с помощью одного из известных вам инструментов.
# 6. Выбрать лучшую модель и проверить её качество.
#     - Выбор делать на основе  метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»). Напишите функцию, которая принимает на вход массивы NumPy или объекты Series в pandas и возвращает значение метрики SMAPE. Используйте эту метрику при подборе гиперпараметров и оценке качества моделей. Критерий успеха: SMAPE ≤15 на тестовой выборке. В решении сохраните работу со всеми моделями, которые вы пробовали. Сделайте выводы.
# 7. Оформить вывод
#     - Сделать промежуточные выводы о том, какая модель справилась лучше и почему.
#
# Исходные данные:
#
# - Тренировочная выборка:
#     - train_job_satisfaction_rate.csv
# - Входные признаки тестовой выборки:
#     - test_features.csv
# - Целевой признак тестовой выборки:
#     - test_target_job_satisfaction_rate.csv
#
# **Цель №2: Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании**
#
# Для этой задачи могут быть использованы те же входные признаки, что и в предыдущей задаче. Однако целевой признак отличается: это quit — увольнение сотрудника из компании.
#
# 1. Исследовать общую информация о датафреймах
#     - Тренировочная выборка: train_quit.csv
#     - Входные признаки тестовой выборки те же, что и в прошлой задаче: test_features.csv
#     - Целевой признак тестовой выборки: test_target_quit.csv
# 2. Выполнить предобработку данных:
#     - Обработка пропущенных значений
#     - Обработка неявных дубликатов
#     - Обработка явных дубликатов
#     - Изменение типов данных
#     - Выявление и обработка аномальных значений
# 3. Выполнить исследовательский и статистический анализ данных
#     - Составьте портрет «уволившегося сотрудника». Например, можно узнать, в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Также можно сравнить среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании.
#     - Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Проверьте это утверждение: визуализируйте и сравните распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используйте данные с обоими целевыми признаками тестовой выборки.
# 4. Добавить новый входной признак
#     - Допустим, job_satisfaction_rate и quit действительно связаны и вы получили необходимое значение метрики в первой задаче. Тогда добавьте job_satisfaction_rate, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.
# 5. Подготовка данных для модели
#     - Подготовьте признаки так же, как и в первой задаче: выполните подготовку в пайплайне, дополнив пайплайн предобработки. При кодировании учитывайте особенности признаков и моделей и используйте как минимум два кодировщика.
# 6. Обучить модели
#     - Обучить как минимум три модели. Как минимум для двух из них подберите гиперпараметры. Проверьте качество лучшей модели. Метрика оценки качества в этой задаче — ROC-AUC. Критерий успеха: ROC-AUC ≥0.91 на тестовой выборке. Напомним: отбор признаков часто помогает улучшить метрику.
# 7. Сформулировать вывод
#     - Сделайте промежуточные выводы о том, какая модель справилась лучше и почему.
#
# Исходные данные:
#
# - Тренировочная выборка:
#     - train_quit.csv
# - Входные признаки тестовой выборки те же, что и в прошлой задаче:
#     - test_features.csv
# - Целевой признак тестовой выборки:
#     - test_target_quit.csv
#
#
# **Сформулировать общий вывод:**
# - опишите задачу;
# - опишите все этапы работы;
# - добавьте выводы и дополнительные предложения для бизнеса.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ## Импорт библиотек, загрузка данных, константы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Установка библиотек

# %%
# !pip install -q  phik

# %%
# !pip install -q -U scikit-learn

# %%
# !pip install -q shap

# %%
# !pip install -q optuna

# %% [markdown]
# Импорт библиотек

# %%
#библиотека для работы с данными 
import pandas as pd

#библиотека для вывода данных
from IPython.display import display

#библотеки для графиков
import seaborn as sns
#настройки seaborn
sns.set(style = 'darkgrid') 
sns.set(rc={'figure.figsize': (15, 6)}) 
sns.set_context('notebook', rc={'font.size': 10, 
                                'axes.titlesize': 10, 
                                'axes.labelsize': 10, 
                                'xtick.labelsize': 'small', 
                                'ytick.labelsize': 'small', 
                                'legend.fontsize': 'small', 
                                'legend.title_fontsize': 10})

import matplotlib.pyplot as plt

#библотека для корреляционного анализа
import phik

from scipy import stats as st

from sklearn.model_selection import train_test_split 

#математические библиотеки
from math import factorial, ceil
import numpy as np

#метрики
from sklearn.metrics import (
    r2_score,
    mean_squared_error,
    mean_absolute_error,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix
)
import shap

#разделение данных, кросс-валидация с пользовательской метрикой
from sklearn.model_selection import train_test_split, cross_val_score

#Оценка permutation importance
from sklearn.inspection import permutation_importance

# загружаем класс pipeline
from sklearn.pipeline import Pipeline

from sklearn.compose import ColumnTransformer

# загружаем классы для подготовки данных
from sklearn.preprocessing import (
    OneHotEncoder, 
    OrdinalEncoder, 
    StandardScaler, 
    MinMaxScaler, 
    RobustScaler
)

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем функцию для работы с метриками
from sklearn.metrics import (
    roc_auc_score,
    roc_curve,
    RocCurveDisplay,
    make_scorer
)
#библиотека метода опорных векторов
from sklearn.svm import SVC

# импортируем классы поиска
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from optuna import distributions
from optuna.integration import OptunaSearchCV

# загружаем нужные модели
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

# %% [markdown]
# Загрузка данных

# %%
#Цель 1
#Тренировочная выборка:
df_train_job_satisfaction_rate = pd.read_csv('/datasets/train_job_satisfaction_rate.csv', decimal=",", sep=',')

#Входные признаки тестовой выборки:
df_test_features = pd.read_csv('/datasets/test_features.csv', decimal=",", sep=',')

#Целевой признак тестовой выборки:
df_test_target_job_satisfaction_rate = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv', decimal=",", sep=',')

#Цель 2
#Тренировочная выборка:
df_train_quit = pd.read_csv('/datasets/train_quit.csv', decimal=",", sep=',')
                            
#Входные признаки тестовой выборки те же, что и в прошлой задаче:
#df_test_features
                            
#Целевой признак тестовой выборки:
df_test_target_quit = pd.read_csv('/datasets/test_target_quit.csv', decimal=",", sep=',')

# %% [markdown]
# Константы

# %%
# создание константы RANDOM_STATE
# константа используется для моделей машинного обучения
# чтобы при каждом перезапуске блокнота датасет делился на выборки одинаково.
RANDOM_STATE = 42
#размер тестовой выборки
TEST_SIZE = 0.25
#Список датафреймов Цели 1
GOAL_ONE_DF_LIST = [df_train_job_satisfaction_rate, 
                    df_test_features, 
                    df_test_target_job_satisfaction_rate]

GOAL_ONE_DF_LIST_LABELS = ['df_train_job_satisfaction_rate', 
                           'df_test_features', 
                           'df_test_target_job_satisfaction_rate']

#Список наименований для графиков датафреймов Цели 1
DF_TRAIN_JOB_SATISFACTION_RATE_X_LABELS = ['Идентификатор',
                                           'Отдел',
                                           'Квалификация',
                                           'Рабочая нагрузка',
                                           'Стаж',
                                           'Повышение за последний год',
                                           'Нарушения за последний год',
                                           'Оценка руководителя',
                                           'Зарплата',
                                           'Уровень удовлетворенности работой']

DF_TRAIN_JOB_SATISFACTION_RATE_Y_LABELS = ['Кол-во',
                                           'nan',
                                           'nan',
                                           'nan',
                                           'Годы',
                                           'nan',
                                           'nan',
                                           'Баллы',
                                           'Руб.',
                                           'Коэффициент']

DF_TEST_FEATURES_X_LABELS = ['Идентификатор',
                             'Отдел',
                             'Квалификация',
                             'Рабочая нагрузка',
                             'Стаж',
                             'Повышение за последний год',
                             'Нарушения за последний год',
                             'Оценка руководителя',
                             'Зарплата']

DF_TEST_FEATURES_Y_LABELS = ['Кол-во',
                             'nan',
                             'nan',
                             'nan',
                             'Годы',
                             'nan',
                             'nan',
                             'Баллы',
                             'Руб.']

DF_TEST_TARGET_JOB_SATISFACTION_RATE_X_LABELS = ['Идентификатор',
                                                 'Уровень удовлетворенности работой']

DF_TEST_TARGET_JOB_SATISFACTION_RATE_Y_LABELS = ['Кол-во',
                                                 'Коэффициент']

#Список датафреймов Цели 2

GOAL_TWO_DF_LIST = [df_train_quit, 
                    df_test_features, 
                    df_test_target_quit]

GOAL_TWO_DF_LIST_LABELS = ['df_train_quit', 
                           'df_test_features', 
                           'df_test_target_quit']

#Список наименований для графиков датафреймов Цели 2

DF_TRAIN_QUIT_X_LABELS = ['Идентификатор',
                          'Отдел',
                          'Квалификация',
                          'Рабочая нагрузка',
                          'Стаж',
                          'Повышение за последний год',
                          'Нарушения за последний год',
                          'Оценка руководителя',
                          'Зарплата',
                          'Увольнение сотрудника']

DF_TRAIN_QUIT_Y_LABELS = ['Кол-во',
                          'nan',
                          'nan',
                          'nan',
                          'Годы',
                          'nan',
                          'nan',
                          'Баллы',
                          'Руб.',
                          'nan']

DF_TEST_TARGET_QUIT_X_LABELS = ['Идентификатор',
                                'Увольнение сотрудника']

DF_TEST_TARGET_QUIT_Y_LABELS = ['Кол-во',
                                'Увольнение сотрудника']

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ## Функции, используемые в проекте
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ### nice_t - Функция форматирования таблиц

# %%
def nice_t(data):
    
    #Функция для форматирования вывода таблиц
    th_props = [
      ('font-size', '11px'),
      ('text-align', 'center'),
      ('font-weight', 'bold'),
      ('color', 'black'),
      ('background-color', '#40E0D0')
      ]
    td_props = [
      ('font-size', '12px'),
      ('text-align', 'center')
      ]
    tr_props = [
      ('background-color', '#40E0D0'),
      ('text-align', 'center')  
        ]
    tr_nth_child_props = [
      ('background-color', '#CFECEC')  
        ]

    styles = [
      dict(selector="th", props=th_props),
      dict(selector="td", props=td_props),
      dict(selector="tr:nth-child(even)", props=tr_nth_child_props),
      dict(selector="tr:hover", props=tr_props)  
      ]
    display(data.style.set_table_styles(styles))

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### data_info - Функция вывода информации о датафрейме

# %%
def data_info (data, figsize_x, figsize_y):
    
    '''
    Функция выводит основную информацию о датафрейме
    в удобном формате
    '''
    print('\nОбщая информация о датафрейме .head()\n')
    nice_t(data.head())
    print('\nОбщая информация о датафрейме .info()\n')
    display(data.info())
    print('\nОбщая информация о датафрейме .describe()\n')
    print('\nКоличество пропусков в датафрейме\n', data.isna().sum())
    print('\nСоотношение пропусков в датафрейме, %\n', round(data.isna().sum() / len(data) * 100, 2))
    nice_t(data.describe())
    print('\nОбщая информация о датафрейме .hist()\n')
    try:
        data.hist(color='#000080',bins=50, figsize=(figsize_x, figsize_y))
        plt.show()
    except: 
        print('Построение гистограммы невозможно. Отсутствуют подходящие данные')

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### data_category_analyze - Функция вывода круговых диаграмм категориальных данных

# %%
def data_category_analyze(data, exclude_col, labels):
    
    #Функция выводит круговые диаграммы по категориям

    #создадим датафрейм без столбцов exclude_col
    try:
        data_excluded = data.drop(exclude_col, axis=1)
    except:
        print('Не обнаружено столбцов для исключения')
        data_excluded = data
    #создадим датафрейм с наименованиями labels
    df_labels = pd.DataFrame(columns=data.columns.to_list())
    df_labels.loc[len(df_labels)] = labels

    #задаём количество строк и столбцов в subplots
    ncols = 3
    # расчет количества строк
    nrows = len(data_excluded.select_dtypes(exclude={'int64', 'float64'}).columns) // ncols + \
           (len(data_excluded.select_dtypes(exclude={'int64', 'float64'}).columns) % ncols > 0)
    #цикл для вывода круговых диаграмм
    plt.figure(figsize=(15, 10))
    for num, column in enumerate(data_excluded.select_dtypes(exclude={'int64', 'float64'})):
        ax = plt.subplot(nrows, ncols, num + 1)
        pivot_table = data.pivot_table(index=column, values='id', aggfunc=['count'])
        pivot_table.columns = [column]
        pivot_table.plot(kind='pie',
                         y=column,
                         title=f'Распределение по {df_labels[column].values[0]}',
                         labels = pivot_table.index,
                         colors=sns.color_palette('Accent'),
                         ylabel='',
                         legend=False,
                         radius=1,
                         autopct='%.1f%%',
                         textprops={'size': 'medium'},
                         ax=ax)     
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### data_numbers_analyze - Функция анализа числовых данных

# %%
def data_numbers_analyze(data, exclude_col, x_labels, y_labels, figsize_x, figsize_y):
    
    '''
    Функция выводит общую информацию о датафрейме(describe)
    Выводит диаграммы размаха с группировкой по категориям

    '''
    
    #создадим датафрейм без столбцов exclude_col
    try:
        data_excluded = data.drop(exclude_col, axis=1)
    except:
        print('Не обнаружено столбцов для исключения')
        data_excluded = data

    #создадим датафрейм с наименованиями labels
    df_labels = pd.DataFrame(columns=data.columns.to_list())
    df_labels.loc[len(df_labels)] = x_labels
    df_labels.loc[len(df_labels)] = y_labels
    #создадим цикл для вывода информации
    print ('\nИсследование числовых значений\n')
    print('\nОбщая информация о данных (describe)\n')
    nice_t(data_excluded.describe())
    
    #задаём количество строк и столбцов в subplots
    ncols = 3
    # расчет количества строк
    nrows = len(data_excluded.select_dtypes(include={'int64', 'float64'}).columns) // ncols + \
           (len(data_excluded.select_dtypes(include={'int64', 'float64'}).columns) % ncols > 0)
    #цикл для вывода круговых диаграмм
    plt.figure(figsize=(figsize_x, figsize_y))
    for num, column in enumerate(data_excluded.select_dtypes(include={'int64', 'float64'})):
        ax = plt.subplot(nrows, ncols, num + 1)
        sns.set_style("darkgrid")
        boxplot = sns.boxplot(y=data_excluded[column], ax=ax, width=0.3)
        boxplot.axes.set_title(f"Диаграмма размаха {df_labels[column].values[0]}", fontsize=10)
        boxplot.set_xlabel(df_labels[column].values[0], fontsize=10)
        boxplot.set_ylabel(df_labels[column].values[1], fontsize=10)   
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### data_hist_analyze - Функция вывода гистограммы распределения числовых значений

# %%
def data_hist_analyze(data, exclude_col, x_labels, y_labels):
  
    '''
    Функция выводит гистограммы
    Для статистической проверки принадлежности нормальному распределению применим тест Шапиро-Уилка. 
    Нулевая гипотеза H0 теста Шапиро–Уилка заключается в том, что случайная величина, 
    выборка x которой известна, распределена по нормальному закону. Альтернативная гипотеза H1 заключается в том,
    что закон распределения не является нормальным. 
    Величина близкая к 1 означает, что распределение близко к нормальному
    '''    
    #создадим датафрейм без столбцов exclude_col
    data_excluded = data.drop(exclude_col, axis=1)
    #создадим датафрейм с наименованиями labels
    df_labels = pd.DataFrame(columns=data.columns.to_list())
    df_labels.loc[len(df_labels)] = x_labels
    df_labels.loc[len(df_labels)] = y_labels

    #создадим цикл для оценки распределения числовых данных при помощи histplot
          
    for j in data_excluded.select_dtypes(include={'int64', 'float64'}):
        fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,5))
        sns.set_style("darkgrid")
        histplot = sns.histplot(data=data_excluded, x=j, color="blue", label=j, kde='true', bins='auto')
        histplot.axes.set_title(f'Гистограмма распределения {df_labels[j].values[0]}', fontsize=10)
        histplot.set_xlabel(df_labels[j].values[0], fontsize=10)
        histplot.set_ylabel('Кол-во', fontsize=10)
        plt.show()
        stat, p = st.shapiro(data_excluded[j])
        print('stat=%.3f, p=%.3f\n' % (stat, p))
        if p > 0.05:
            print('Вероятно, распределение нормальное (Гауссово)')
        else:
            print('Вероятно, распределение не нормальное (не Гауссово)')

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### find_mode - Функция нахождения моды с определенными условиями

# %%
def find_mode (data, columns, nan_rows_col, search_col):
    
    #функция предназначена для того, чтобы найти моду в пропущенных значениях строк
    #по всему датафрейму
    #при условиях, которые задаются в функции
    
    #создаём список условий
    condition = []
    #создаём список, куда записываются условия (>,<, == и т.д.)
    equal = []
    
    #задаём условия
    for i in columns:
        equal.append('==')
    
    #цикл выводит моду (наиболее часто встречающееся значение, с группировкой по столбцам columns)
    for value in data[data[nan_rows_col].isna()][search_col].to_list():
        
        for value_2 in columns:
            condition.append(data[data[search_col] == value][value_2].values[0])
            
        query = ' & '.join(f'{i} {j} {repr(k)}' for i, j, k in zip(columns, equal, condition))
        print(f'Мода пропущенного значения {value} столбца {search_col}: {data.query(query)[nan_rows_col].mode().values[0]}')
        condition.clear()

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### find_duplicates - Функция нахождения явных дубликатов в списке датафреймов

# %%
def find_duplicates (data_list, data_list_labels):
    
    #Функция находит явные дубликаты в списке датафреймов
    
    for num, data in enumerate(data_list):
        print(f'\nКоличество дубликатов в датафрейме\n {data_list_labels[num]} : ', data.duplicated().sum())

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### find_nans - Функция нахождения пропусков в списке датафреймов

# %%
def find_nans (data_list, data_list_labels):
    
    for num, data in enumerate(data_list):
        print(f'\nКоличество пропусков в датафрейме\n {data_list_labels[num]} : \n', data.isna().sum())

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### hist_comparison - Функция построения плотности распределения тренировочной и тестовой выборок

# %%
def hist_comparison(data_train, data_test, exclude_col_1, exclude_col_2, x_labels, y_labels):
    
    #функция предназначена для сравнения плотности распределения
    
    #data_1
    #создадим датафрейм без столбцов exclude_col
    data_train_excluded = data_train.drop(exclude_col_1, axis=1)
    
    #создадим датафрейм с наименованиями labels
    df_labels = pd.DataFrame(columns=data_train.columns.to_list())
    df_labels.loc[len(df_labels)] = x_labels
    df_labels.loc[len(df_labels)] = y_labels
    
    #data_2
    #создадим датафрейм без столбцов exclude_col
    data_test_excluded = data_test.drop(exclude_col_2, axis=1)
    
    #цикл для сравнения распределения числовых данных при помощи histplot
          
    for j in data_train_excluded.select_dtypes(include={'int64', 'float64'}):
        #fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,5))
        histplot = sns.histplot(data=data_train_excluded, 
                                x=j, 
                                color="green", 
                                label='Train', 
                                kde='true',
                                alpha = 0.5,
                                stat='density',
                                bins=100)
        
        histplot = sns.histplot(data=data_test_excluded, 
                                x=j, 
                                color="orange", 
                                label='Test', 
                                kde='true',
                                alpha = 0.5,
                                stat='density',
                                bins=100)
        histplot.legend()
        histplot.axes.set_title(f'Гистограммы плотности распределения {df_labels[j].values[0]}', fontsize=10)
        histplot.set_xlabel(df_labels[j].values[0], fontsize=10)
        histplot.set_ylabel('Плотность', fontsize=10)
        plt.show()

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### smape_calc - Функция вычисления метрики SMAPE

# %%
def smape_calc (y_pred, y_test):
    return np.mean(np.abs(y_pred - y_test) / ((np.abs(y_pred) + np.abs(y_test))/2) )*100

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ### IQR_cat_make - Функция преобразования числовых  данных в категориальные

# %%
def IQR_cat_make(data, col, cat_1, cat_2, cat_3, cat_4, cat_5):
    
    #Функция изменяет значения в столбце на категориальные
    #Всё, что ниже нижнего квартиля Q1 относится к cat_1
    #Всё, что находится между нижним и верхним квартилем к cat_2
    #Всё, что выше верхнего квартиля Q3 - к cat_3
    #возвращает столбец с модифицированными данными
    
    #присвоим значения квартилей
    Q3 = np.quantile(data[col], 0.75)
    Q1 = np.quantile(data[col], 0.25)
    IQR = Q3 - Q1
    low_lim = Q1 - 1.5 * IQR
    up_lim = Q3 + 1.5 * IQR

    data[col] = data[col].apply(lambda x: 
                                cat_1 if x < Q1
                                else cat_2 if low_lim <= x <= Q1
                                else cat_3 if Q1 < x < Q3
                                else cat_4 if Q3 < x < up_lim
                                else cat_5)

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ## Цель №1: Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ### Общая информация о данных
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Описание данных train_job_satisfaction_rate.csv
#
# [К оглавлению]

# %% [markdown]
# -   `id` — уникальный идентификатор сотрудника;
# -   `dept` — отдел, в котором работает сотрудник;
# -   `level` — уровень занимаемой должности;
# -   `workload` — уровень загруженности сотрудника;
# -   `employment_years` — длительность работы в компании (в годах);
# -   `last_year_promo` — показывает, было ли повышение за последний год;
# -   `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год;
# -   `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель;
# -   `salary` — ежемесячная зарплата сотрудника;
# -   `job_satisfaction_rate` — уровень удовлетворённости сотрудника работой в компании, целевой признак.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Общие сведения train_job_satisfaction_rate.csv
#
# [К оглавлению]

# %%
data_info(df_train_job_satisfaction_rate , 15, 5)
# Out:
# Общая информация о датафрейме .head()
# <style  type="text/css" >
#     #T_24c8b_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_24c8b_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_24c8b_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_24c8b_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Обнаружены пропуски в столбцах:
#     - dept: 6
#     - level: 4
#
# **Тип данных и аномальные значения:**
#
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 1.   dept                   `object` : тип данных соответствует.
# 2.   level                  `object` : тип данных соответствует.
# 3.   workload               `object` : тип данных соответствует.
# 4.   employment_years       `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 5.   last_year_promo        `object` : тип данных соответствует.
# 6.   last_year_violations   `object` : тип данных соответствует.
# 7.   supervisor_evaluation  `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 8.   salary                 `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Значений выше 60000 относительно мало.
# 9.   job_satisfaction_rate  `object` : **тип данных не соответствует. Требуется дополнительное исследование.**

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Описание данных test_features.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# -   `id` — уникальный идентификатор сотрудника;
# -   `dept` — отдел, в котором работает сотрудник;
# -   `level` — уровень занимаемой должности;
# -   `workload` — уровень загруженности сотрудника;
# -   `employment_years` — длительность работы в компании (в годах);
# -   `last_year_promo` — показывает, было ли повышение за последний год;
# -   `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год;
# -   `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель;
# -   `salary` — ежемесячная зарплата сотрудника;

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Общие сведения test_features.csv
#
# [К оглавлению](#Оглавление)

# %%
data_info(df_test_features, 15, 5)
# Out:
# Общая информация о датафрейме .head()
# <style  type="text/css" >
#     #T_2e20e_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_2e20e_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_2e20e_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_2e20e_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Обнаружены пропуски в столбцах:
#     - dept: 2
#     - level: 1
#
# **Тип данных и аномальные значения:**
#
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 1.   dept                   `object` : тип данных соответствует.
# 2.   level                  `object` : тип данных соответствует.
# 3.   workload               `object` : тип данных соответствует.
# 4.   employment_years       `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 5.   last_year_promo        `object` : тип данных соответствует.
# 6.   last_year_violations   `object` : тип данных соответствует.
# 7.   supervisor_evaluation  `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 8.   salary                 `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Значений выше 60000 относительно мало.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Описание данных test_target_job_satisfaction_rate.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# -   `id` — уникальный идентификатор сотрудника;
# -   `job_satisfaction_rate` — уровень удовлетворённости сотрудника работой в компании, целевой признак.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Общие сведения test_target_job_satisfaction_rate.csv
#
# [К оглавлению](#Оглавление)

# %%
data_info(df_test_target_job_satisfaction_rate, 5, 5)
# Out:
# Общая информация о датафрейме .head()
# <style  type="text/css" >
#     #T_b6336_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_b6336_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_b6336_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_b6336_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
#     }</style><table id="T_b6336_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >job_satisfaction_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6336_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b6336_row0_col0" class="data row0 col0" >130604</td>
# ...

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Пропусков не обнаружено
#
# **Тип данных и аномальные значения:**
#
# 1.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 2.   job_satisfaction_rate  `object` : **тип данных не соответствует. Требуется дополнительное исследование.**

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# <a id='chapter_one_conlusion'></a>

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Был проведен предварительный анализ предоставленных заказчиком данных, были обозначены обнаруженные некоторые дефекты данных, выявлены дальнейшие задачи для исследования.
#
# **train_job_satisfaction_rate.csv**
#
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Обнаружены пропуски в столбцах:
#     - dept: 6
#     - level: 4
#
# **Тип данных и аномальные значения:**
#
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 1.   dept                   `object` : тип данных соответствует.
# 2.   level                  `object` : тип данных соответствует.
# 3.   workload               `object` : тип данных соответствует.
# 4.   employment_years       `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 5.   last_year_promo        `object` : тип данных соответствует.
# 6.   last_year_violations   `object` : тип данных соответствует.
# 7.   supervisor_evaluation  `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 8.   salary                 `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Значений выше 60000 относительно мало.
# 9.   job_satisfaction_rate  `object` : **тип данных не соответствует. Требуется дополнительное исследование.**
#
# **test_features.csv**
#
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Обнаружены пропуски в столбцах:
#     - dept: 2
#     - level: 1
#
# **Тип данных и аномальные значения:**
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 1.   dept                   `object` : тип данных соответствует.
# 2.   level                  `object` : тип данных соответствует.
# 3.   workload               `object` : тип данных соответствует.
# 4.   employment_years       `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 5.   last_year_promo        `object` : тип данных соответствует.
# 6.   last_year_violations   `object` : тип данных соответствует.
# 7.   supervisor_evaluation  `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 8.   salary                 `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Значений выше 60000 относительно мало.
#
#
#
# **test_target_job_satisfaction_rate.csv**
#
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Пропусков не обнаружено
#
# **Тип данных и аномальные значения:**
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
#
# 1.   job_satisfaction_rate  `object` : **тип данных не соответствует. Требуется дополнительное исследование.**
#
# Дальнейшее исследование распределения значений будет производится в разделе исследовательского анализа

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Предобработка данных
#
# [К оглавлению](#Оглавление)
#
# Изучите данные и сделайте выводы. При необходимости выполните предобработку. Если есть
# пропуски, заполните их в пайплайне.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Замена наименований столбцов
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# В соответствии с [выводами главы 5.1](#chapter_one_conlusion) замена наименований столбцов не требуется

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Преобразование типов данных
#
# [К оглавлению](#Оглавление)
#
# В соответствии с [выводами главы 5.1](#chapter_one_conlusion) были обнаружены несоответствия типов данных в столбце `job_satisfaction_rate`
#
# Заменим тип данных

# %%
print('\nТипы данных до преобразования\n\n', df_train_job_satisfaction_rate.dtypes)
df_train_job_satisfaction_rate = df_train_job_satisfaction_rate.apply(pd.to_numeric, errors='ignore')
print('\nТипы данных после преобразования \n\n', df_train_job_satisfaction_rate.dtypes)
# Out:
# Типы данных до преобразования
#
#  id                        int64
# dept                     object
# level                    object
# workload                 object
# employment_years          int64
# last_year_promo          object
# last_year_violations     object
# supervisor_evaluation     int64
# salary                    int64
# job_satisfaction_rate    object
# dtype: object
#
# Типы данных после преобразования
#
#  id                         int64
# dept                      object
# level                     object
# workload                  object
# employment_years           int64
# last_year_promo           object
# last_year_violations      object
# supervisor_evaluation      int64
# salary                     int64
# job_satisfaction_rate    float64
# dtype: object

# %%
print('\nТипы данных до преобразования\n\n', df_test_target_job_satisfaction_rate.dtypes)
df_test_target_job_satisfaction_rate = df_test_target_job_satisfaction_rate.apply(pd.to_numeric, errors='ignore')
print('\nТипы данных после преобразования \n\n', df_test_target_job_satisfaction_rate.dtypes)
# Out:
# Типы данных до преобразования
#
#  id                        int64
# job_satisfaction_rate    object
# dtype: object
#
# Типы данных после преобразования
#
#  id                         int64
# job_satisfaction_rate    float64
# dtype: object

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# **Преобразование типов данных:**
#
# - df_train_job_satisfaction_rate
#     - Были заменены типы данных столбца `job_satisfaction_rate`: `object` => `float`
#
# - df_test_features
#     - преобразование типов данных не требуется
#
# - df_test_target_job_satisfaction_rate
#     - Были заменены типы данных столбца `job_satisfaction_rate`: `object` => `float`

# %%
df_train_job_satisfaction_rate['dept'].unique()
# Out:
# array(['sales', 'hr', 'technology', 'purchasing', 'marketing', nan],
#       dtype=object)

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Обработка явных дубликатов
#
# [К оглавлению](#Оглавление)

# %%
find_duplicates(GOAL_ONE_DF_LIST, GOAL_ONE_DF_LIST_LABELS)
# Out:
# Количество дубликатов в датафрейме
#  df_train_job_satisfaction_rate :  0
#
# Количество дубликатов в датафрейме
#  df_test_features :  0
#
# Количество дубликатов в датафрейме
#  df_test_target_job_satisfaction_rate :  0

# %%
find_duplicates([df_train_job_satisfaction_rate['id'], 
                 df_test_features['id'], 
                 df_test_target_job_satisfaction_rate['id']], 
                 GOAL_ONE_DF_LIST_LABELS)
# Out:
# Количество дубликатов в датафрейме
#  df_train_job_satisfaction_rate :  0
#
# Количество дубликатов в датафрейме
#  df_test_features :  0
#
# Количество дубликатов в датафрейме
#  df_test_target_job_satisfaction_rate :  0

# %% [markdown]
# <a id='duplicates_cell'></a>

# %%
find_duplicates([df_train_job_satisfaction_rate.loc[:, df_train_job_satisfaction_rate.columns !='id'], 
                 df_test_features.loc[:, df_test_features.columns !='id'], 
                 df_test_target_job_satisfaction_rate.loc[:, df_test_target_job_satisfaction_rate.columns !='id']], 
                 GOAL_ONE_DF_LIST_LABELS)
# Out:
# Количество дубликатов в датафрейме
#  df_train_job_satisfaction_rate :  245
#
# Количество дубликатов в датафрейме
#  df_test_features :  557
#
# Количество дубликатов в датафрейме
#  df_test_target_job_satisfaction_rate :  1902

# %% [markdown]
# Как видно, в тренировочной выборке, если не учитывать id, присутствует множество сотрудников с одинаковыми признаками, что может навредить модели. Решение по их удалению примем в соответствующем разделе
#
# Повторяющиеся значения в `df_test_target_job_satisfaction_rate` возможны и допустимы.

# %% [markdown]
# Проверим, не имеется ли дубликатов в объединенных тестовой и тренировочной выборках

# %%
df_test_merged = df_test_features.merge(df_test_target_job_satisfaction_rate, on='id')

# %%
df_full = pd.concat([
    df_train_job_satisfaction_rate,
    df_test_merged
])

# %%
print(f'\nКоличество дубликатов в датафрейме df_full : \n', df_full.duplicated().sum())
# Out:
# Количество дубликатов в датафрейме df_full :
#  0

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Обработка явных дубликатов**
#
# Явных дубликатов не обнаружено

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Обработка неявных дубликатов, опечаток, ошибок, аномальных значений строковых данных
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### train_job_satisfaction_rate.csv

# %%
for col in df_train_job_satisfaction_rate.select_dtypes(include='object'):
    print('\nНаименование столбца: ',col)
    print(df_train_job_satisfaction_rate[col].unique())
# Out:
# Наименование столбца:  dept
# ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
#
# Наименование столбца:  level
# ['junior' 'middle' 'sinior' nan]
#
# Наименование столбца:  workload
# ['medium' 'high' 'low']
#
# Наименование столбца:  last_year_promo
# ['no' 'yes']
#
# Наименование столбца:  last_year_violations
# ['no' 'yes']

# %% [markdown]
# В столбце level обнаружена опечатка/ошибка в слове `sinior`, исправим её.

# %%
df_train_job_satisfaction_rate.replace({'sinior': 'senior'},inplace=True)

# %%
for col in df_train_job_satisfaction_rate.select_dtypes(include='object'):
    print('\nНаименование столбца: ',col)
    print(df_train_job_satisfaction_rate[col].unique())
# Out:
# Наименование столбца:  dept
# ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
#
# Наименование столбца:  level
# ['junior' 'middle' 'senior' nan]
#
# Наименование столбца:  workload
# ['medium' 'high' 'low']
#
# Наименование столбца:  last_year_promo
# ['no' 'yes']
#
# Наименование столбца:  last_year_violations
# ['no' 'yes']

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **train_job_satisfaction_rate.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`

# %% [markdown]
# ##### test_features.csv

# %%
for col in df_test_features.select_dtypes(include='object'):
    print('\nНаименование столбца: ',col)
    print(df_test_features[col].unique())
# Out:
# Наименование столбца:  dept
# ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
#
# Наименование столбца:  level
# ['junior' 'middle' 'sinior' nan]
#
# Наименование столбца:  workload
# ['medium' 'low' 'high' ' ']
#
# Наименование столбца:  last_year_promo
# ['no' 'yes']
#
# Наименование столбца:  last_year_violations
# ['no' 'yes']

# %% [markdown]
# В столбцах `dept` и `workload` обнаружены пропущенные значения ' '. Заменим их в pipeline. А также исправим ошибку в слове `sinior`

# %%
#df_test_features.replace({' ': np.nan},inplace=True)

# %%
df_test_features.replace({'sinior': 'senior'},inplace=True)

# %%
for col in df_test_features.select_dtypes(include='object'):
    print('\nНаименование столбца: ',col)
    print(df_test_features[col].unique())
# Out:
# Наименование столбца:  dept
# ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
#
# Наименование столбца:  level
# ['junior' 'middle' 'senior' nan]
#
# Наименование столбца:  workload
# ['medium' 'low' 'high' ' ']
#
# Наименование столбца:  last_year_promo
# ['no' 'yes']
#
# Наименование столбца:  last_year_violations
# ['no' 'yes']

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **test_features.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
# - В столбцах `dept` и `workload` обнаружены пропущенные значения ' '. Заменены на np.nan

# %% [markdown]
# ##### test_target_job_satisfaction_rate.csv

# %%
df_test_target_job_satisfaction_rate.dtypes
# Out:
# id                         int64
# job_satisfaction_rate    float64
# dtype: object

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
# Столбцы с типом object отсутствуют

# %% [markdown]
# Так как были обнаружены новые пропуски в данных, проверим их ещё раз для дальнейшей обработки

# %%
find_nans(GOAL_ONE_DF_LIST, GOAL_ONE_DF_LIST_LABELS)
# Out:
# Количество пропусков в датафрейме
#  df_train_job_satisfaction_rate :
#  id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64
#
# Количество пропусков в датафрейме
#  df_test_features :
#  id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# dtype: int64
#
# Количество пропусков в датафрейме
#  df_test_target_job_satisfaction_rate :
#  id                       0
# job_satisfaction_rate    0
# dtype: int64

# %% [markdown]
# #### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# **train_job_satisfaction_rate.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
#
# **test_features.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
# - В столбцах `dept` и `workload` обнаружены пропущенные значения ' '. Заменены на np.nan
# - Были обнаружены пропуски в столбце `dept`, `workload`
#
# **test_target_job_satisfaction_rate.csv**
#
# - Столбцы с типом object отсутствуют

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Обработка пропущенных значений
# [К оглавлению](#Оглавление)
#
# Если есть пропуски, заполните их в пайплайне.

# %% [markdown]
# ##### Обработка пропущенных значений train_job_satisfaction_rate.csv
#
# [К оглавлению](#Оглавление)
#
# Если есть пропуски, заполните их в пайплайне.
#
# В соответствии с [выводами главы 5.1](#chapter_one_conlusion) были обнаружены пропуски:
# - dept: 6
# - level: 4
#
# Рассмотрим более подробно.

# %%
nice_t(df_train_job_satisfaction_rate[df_train_job_satisfaction_rate['dept'].isna()])
# Out:
# <style  type="text/css" >
#     #T_9fce4_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_9fce4_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_9fce4_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_9fce4_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %% [markdown]
# Как видно из таблицы, строки с пропусками имеют разные значения. Как правило, сотрудники из одного отдела, с одинаковым уровнем загрузки, уровня квалификации имеют одинаковый оклад. Проверим наиболее встречающиеся значения для таких сотрудников.

# %%
find_mode(df_train_job_satisfaction_rate, ['salary', 'level', 'workload'], 'dept', 'id')
# Out:
# Мода пропущенного значения 694746 столбца id: sales
# Мода пропущенного значения 814624 столбца id: sales
# Мода пропущенного значения 475114 столбца id: sales
# Мода пропущенного значения 497243 столбца id: technology
# Мода пропущенного значения 168668 столбца id: sales
# Мода пропущенного значения 641150 столбца id: sales

# %% [markdown]
# Проверим моду для всего столбца без дополнительных условий

# %%
df_train_job_satisfaction_rate['dept'].mode().values[0]
# Out:
# 'sales'

# %% [markdown]
# В данном случае, допустимо будет заполнить пропущенные значения столбца `dept` модой столбца `id`. Проверим второй столбец `level`

# %%
nice_t(df_train_job_satisfaction_rate[df_train_job_satisfaction_rate['level'].isna()])
# Out:
# <style  type="text/css" >
#     #T_46dd9_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_46dd9_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_46dd9_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_46dd9_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %%
find_mode(df_train_job_satisfaction_rate, ['salary', 'dept', 'workload'], 'level', 'id')
# Out:
# Мода пропущенного значения 631073 столбца id: junior
# Мода пропущенного значения 416327 столбца id: junior
# Мода пропущенного значения 135043 столбца id: junior
# Мода пропущенного значения 998838 столбца id: junior

# %%
df_train_job_satisfaction_rate['level'].mode().values[0]
# Out:
# 'junior'

# %% [markdown]
# Здесь ситуация аналогична предыдущей

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
# В результате исследования было выявлено, что пропущенные значения `df_train_job_satisfaction_rate` могут быть заполнены модой соответствующих столбцов

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ##### Обработка пропущенных значений test_features.csv
#
# [К оглавлению](#Оглавление)
#
# Если есть пропуски, заполните их в пайплайне.
#
# В соответствии с [выводами главы 5.1](#chapter_one_conlusion) были обнаружены пропуски:
# - dept: 3
# - level: 1
# - workload: 1
#
# Рассмотрим более подробно.

# %%
nice_t(df_test_features[df_test_features['dept'].isna()])
# Out:
# <style  type="text/css" >
#     #T_8ec6d_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_8ec6d_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_8ec6d_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_8ec6d_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %%
find_mode(df_test_features, ['salary', 'level', 'workload'], 'dept', 'id')
# Out:
# Мода пропущенного значения 609865 столбца id: sales
# Мода пропущенного значения 832342 столбца id: sales

# %%
df_test_features['dept'].mode().values[0]
# Out:
# 'sales'

# %% [markdown]
# <span style='color:green'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %%
nice_t(df_test_features[df_test_features['level'].isna()])
# Out:
# <style  type="text/css" >
#     #T_fddbf_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_fddbf_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_fddbf_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_fddbf_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %%
find_mode(df_test_features, ['salary', 'dept', 'workload'], 'level', 'id')
# Out:
# Мода пропущенного значения 471990 столбца id: junior

# %%
df_test_features['level'].mode().values[0]
# Out:
# 'junior'

# %% [markdown]
# <span style='color:green'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %%
nice_t(df_test_features[df_test_features['workload'].isna()])
# Out:
# <style  type="text/css" >
#     #T_1958f_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_1958f_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_1958f_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_1958f_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %%
find_mode(df_test_features, ['salary', 'level', 'dept'], 'workload', 'id')

# %%
df_test_features['workload'].mode().values[0]
# Out:
# 'medium'

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
#
# В результате исследования было выявлено, что пропущенные значения `df_test_features` могут быть заполнены модой соответствующих столбцов

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ##### Обработка пропущенных значений test_target_job_satisfaction_rate.csv
#
# [К оглавлению](#Оглавление)
#
# Если есть пропуски, заполните их в пайплайне.

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
# В соответствии с [выводами главы 5.1](#chapter_one_conlusion) пропущенных значений не обнаружено

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# **Обработка пропущенных значений**
#
# **Обработка пропущенных значений train_job_satisfaction_rate.csv**
# - В результате исследования было выявлено, что пропущенные значения `df_train_job_satisfaction_rate` могут быть заполнены модой соответствующих столбцов
#
# **Обработка пропущенных значений test_features.csv**
# - В результате исследования было выявлено, что пропущенные значения `df_test_features` могут быть заполнены модой соответствующих столбцов
#
# **Обработка пропущенных значений test_target_job_satisfaction_rate.csv**
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) пропущенных значений не обнаружено

# %% [markdown]
# #### Предварительная обработка аномальных значений
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# В соответствии с [выводами главы 5.1](#chapter_one_conlusion) аномальных значений не обнаружено

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Была произведена предобработка данных. Основные детали представлены ниже:
#
# **Замена наименований столбцов**
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) замена наименований столбцов не требуется
#
# **Преобразование типов данных:**
#
# - df_train_job_satisfaction_rate
#     - Были заменены типы данных столбца `job_satisfaction_rate`: `object` => `float`
#
# - df_test_features
#     - преобразование типов данных не требуется
#
# - df_test_target_job_satisfaction_rate
#     - Были заменены типы данных столбца `job_satisfaction_rate`: `object` => `float`
#
# **Обработка явных дубликатов**
#
# - Явных дубликатов не обнаружено
#
# - Если не учитывать id, присутствует множество сотрудников с одинаковыми признаками, что может навредить модели. Решение по их удалению примем в соответствующем разделе
#
# Повторяющиеся значения в `df_test_target_job_satisfaction_rate` возможны и допустимы.
#
#
# **Обработка неявных дубликатов, опечаток, ошибок, аномальных значений строковых данных**
#
# **train_job_satisfaction_rate.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
#
# **test_features.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
# - В столбцах `dept` и `workload` обнаружены пропущенные значения ' '. Заменены на np.nan
# - Были обнаружены пропуски в столбце `dept`, `workload`
#
# **test_target_job_satisfaction_rate.csv**
#
# - Столбцы с типом object отсутствуют
#
# **Обработка пропущенных значений**
#
# **Обработка пропущенных значений train_job_satisfaction_rate.csv**
# - В результате исследования было выявлено, что пропущенные значения `df_train_job_satisfaction_rate` могут быть заполнены модой соответствующих столбцов
#
# **Обработка пропущенных значений test_features.csv**
# - В результате исследования было выявлено, что пропущенные значения `df_test_features` могут быть заполнены модой соответствующих столбцов
#
# **Обработка пропущенных значений test_target_job_satisfaction_rate.csv**
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) пропущенных значений не обнаружено
#
# **Предварительная обработка аномальных значений**
#
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) аномальных значений не обнаружено

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Исследовательский анализ данных
#
# [К оглавлению](#Оглавление)
#
# Исследуйте все признаки и сделайте выводы о том, как их нужно подготовить.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### train_job_satisfaction_rate.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Категориальные данные

# %%
data_category_analyze(df_train_job_satisfaction_rate, ' ', DF_TRAIN_JOB_SATISFACTION_RATE_X_LABELS )
# Out:
# Не обнаружено столбцов для исключения

# %% [markdown]
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`
# - Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
# - Большинство сотрудников имеет средний уровень зарплаты

# %% [markdown]
# ##### Количественные данные

# %%
data_numbers_analyze(df_train_job_satisfaction_rate, 
                     ['id'], 
                     DF_TRAIN_JOB_SATISFACTION_RATE_X_LABELS, 
                     DF_TRAIN_JOB_SATISFACTION_RATE_Y_LABELS, 
                     15, 
                     8)
# Out:
# Исследование числовых значений
#
#
# Общая информация о данных (describe)
# <style  type="text/css" >
#     #T_1a804_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_1a804_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_1a804_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_1a804_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
#     }</style><table id="T_1a804_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >employment_years</th>        <th class="col_heading level0 col1" >supervisor_evaluation</th>        <th class="col_heading level0 col2" >salary</th>        <th class="col_heading level0 col3" >job_satisfaction_rate</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# Проверим количество значений оценки руководителя равные 1:

# %%
df_train_job_satisfaction_rate.query('supervisor_evaluation == 1')['supervisor_evaluation'].count()
# Out:
# 201

# %% [markdown]
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation`. Логично предположить, что таких оценок может быть очень мало

# %% [markdown]
# ##### Распределение количественных данных

# %%
data_hist_analyze(df_train_job_satisfaction_rate, 
                  ['id'],
                  DF_TRAIN_JOB_SATISFACTION_RATE_X_LABELS,
                  DF_TRAIN_JOB_SATISFACTION_RATE_Y_LABELS)
# Out:
# stat=0.887, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)
# stat=0.886, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)
# stat=0.939, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)
# stat=0.971, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)

# %% [markdown]
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.

# %% [markdown]
# ##### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Категориальные данные**
#
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`
# - Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
# - Большинство сотрудников имеет средний уровень зарплаты
#
# **Количественные данные**
#
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation` и `salary`, но лежат в пределах нормы
#
# **Распределение количественных данных**
#
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### test_features.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Категориальные данные

# %%
data_category_analyze(df_test_features, ' ', DF_TEST_FEATURES_X_LABELS)
# Out:
# Не обнаружено столбцов для исключения

# %% [markdown]
# ##### Количественные данные

# %%
data_numbers_analyze(df_test_features, 
                     'id', 
                     DF_TEST_FEATURES_X_LABELS, 
                     DF_TEST_FEATURES_Y_LABELS, 
                     15, 
                     5)
# Out:
# Исследование числовых значений
#
#
# Общая информация о данных (describe)
# <style  type="text/css" >
#     #T_e1726_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_e1726_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_e1726_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_e1726_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
#     }</style><table id="T_e1726_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >employment_years</th>        <th class="col_heading level0 col1" >supervisor_evaluation</th>        <th class="col_heading level0 col2" >salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1726_level0_row0" class="row_heading level0 row0" >count</th>
# ...

# %% [markdown]
# ##### Распределение количественных данных

# %%
data_hist_analyze(df_test_features, 
                  'id', 
                  DF_TEST_FEATURES_X_LABELS, 
                  DF_TEST_FEATURES_Y_LABELS)
# Out:
# stat=0.882, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)
# stat=0.880, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)
# stat=0.926, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)

# %% [markdown]
# ##### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
# Аномальных значений в тестовой выборке не обнаружено. Распределение также не нормальное.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### test_target_job_satisfaction_rate.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Количественные данные

# %%
data_numbers_analyze(df_test_target_job_satisfaction_rate, 
                     'id', 
                     DF_TEST_TARGET_JOB_SATISFACTION_RATE_X_LABELS, 
                     DF_TEST_TARGET_JOB_SATISFACTION_RATE_Y_LABELS, 
                     10, 
                     5)
# Out:
# Исследование числовых значений
#
#
# Общая информация о данных (describe)
# <style  type="text/css" >
#     #T_41961_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_41961_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_41961_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_41961_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
#     }</style><table id="T_41961_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >job_satisfaction_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41961_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_41961_row0_col0" class="data row0 col0" >2000.000000</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ##### Распределение количественных данных

# %%
data_hist_analyze(df_test_target_job_satisfaction_rate, 
                  'id', 
                  DF_TEST_TARGET_JOB_SATISFACTION_RATE_X_LABELS, 
                  DF_TEST_TARGET_JOB_SATISFACTION_RATE_Y_LABELS)
# Out:
# stat=0.970, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)

# %% [markdown]
# ##### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Аномальных значений в целевом признаке тестовой выборки не обнаружено. Распределение также не нормальное.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ##### Распределение тренировочной и тестовой выборок

# %% [markdown]
# Объединим данные для проверки распределения между тренировочной и тестовой выборками

# %%
hist_comparison(df_train_job_satisfaction_rate, 
                df_test_merged,
                ['id'], 
                ['id'], 
                DF_TRAIN_JOB_SATISFACTION_RATE_X_LABELS, 
                DF_TRAIN_JOB_SATISFACTION_RATE_Y_LABELS)

# %% [markdown]
# ##### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Как видно из гистограмм, плотность распределения между тренировочной и тестовой выборками похожа.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Категориальные данные**
#
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`
# - Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
#
# **Количественные данные**
#
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation` и `salary`, но лежат в пределах нормы, их исключение не требуется
#
# **Распределение количественных данных**
#
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.
#
#
# Гистограмма плотности распределения между тренировочной и тестовой выборками показала сходство.

# %% [markdown]
# ### Корреляционный анализ признаков
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Проверим связь признаков в тренировочной выборке

# %%
df_train_job_satisfaction_rate
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 0     155278       sales  junior   medium                 2              no
# 1     653870          hr  junior     high                 2              no
# 2     184592       sales  junior      low                 1              no
# 3     171431  technology  junior      low                 4              no
# 4     693419          hr  junior   medium                 1              no
# ...      ...         ...     ...      ...               ...             ...
# 3995  457950  technology  junior     high                 2              no
# 3996  957499       sales  junior   medium                 2              no
# 3997  533318       sales  middle      low                 7              no
# 3998  706868       sales  junior   medium                 2              no
# 3999  338347  technology  middle   medium                 5              no
#
# ...

# %%
plt.figure(figsize=(15, 15))
interval_cols = ['employment_years', 'salary', 'job_satisfaction_rate']
sns.heatmap(df_train_job_satisfaction_rate 
            .loc[:,'dept':'job_satisfaction_rate']
            .phik_matrix(verbose=False, interval_cols=interval_cols), 
            annot=True,
            fmt='.2f'
            )
plt.show()

# %% [markdown]
# Проверим связь признаков в объединенном датафрейме

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df_full 
            .loc[:,'dept':'job_satisfaction_rate']
            .phik_matrix(verbose=False, interval_cols=interval_cols), 
            annot=True,
            fmt='.2f'
            )
plt.show()

# %% [markdown]
# Значения между тренировочным и полным датафреймом сопоставимы

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Корреляционный анализ признаков показал, что наибольшее связь между целевым признаком `job_satisfaction_rate` и оценкой руководителя `supervisor_evaluation` - 0.76 и `last_year_violations` - 0.56, остальные признаки имеют невысокие значения. Мультиколлинеарности не обнаружено

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Подготовка данных
#
# [К оглавлению](#Оглавление)
#
# Подготовку признаков выполните в пайплайне, дополнив пайплайн шага предобработки. При
# кодировании учитывайте особенности признаков и моделей и используйте как минимум два
# кодировщика.

# %% [markdown]
# Выведем информацию тренировочной выборки для подбора признаков

# %%
df_train_job_satisfaction_rate.dtypes
# Out:
# id                         int64
# dept                      object
# level                     object
# workload                  object
# employment_years           int64
# last_year_promo           object
# last_year_violations      object
# supervisor_evaluation      int64
# salary                     int64
# job_satisfaction_rate    float64
# dtype: object

# %%
nice_t(df_train_job_satisfaction_rate.head())
# Out:
# <style  type="text/css" >
#     #T_996dc_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_996dc_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_996dc_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_996dc_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %%
for col in df_train_job_satisfaction_rate.select_dtypes(exclude={'int64', 'float64'}).columns:
    print(f'Значения столбца {col} : \n {df_train_job_satisfaction_rate[col].unique().tolist()}')
# Out:
# Значения столбца dept :
#  ['sales', 'hr', 'technology', 'purchasing', 'marketing', nan]
# Значения столбца level :
#  ['junior', 'middle', 'senior', nan]
# Значения столбца workload :
#  ['medium', 'high', 'low']
# Значения столбца last_year_promo :
#  ['no', 'yes']
# Значения столбца last_year_violations :
#  ['no', 'yes']

# %% [markdown]
# - `dept` можно отнести к категориальным данным
# - `level` к ранговым
# - `workload` к ранговым
# - `last_year_promo` к ранговым
# - `last_year_violations` к ранговым
#
# Также к ранговым переменным можно отнести `supervisor_evaluation`

# %%
df_train_job_satisfaction_rate['supervisor_evaluation'].sort_values().unique().tolist()
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Упорядочим данные по id

# %%
df_train_job_satisfaction_rate = df_train_job_satisfaction_rate.sort_values(by='id')
df_test_features = df_test_features.sort_values(by='id')
df_test_target_job_satisfaction_rate = df_test_target_job_satisfaction_rate.sort_values(by='id')

# %% [markdown]
# Проверим размерности датафреймов

# %%
for num, df in enumerate(GOAL_ONE_DF_LIST):
    print(f'Размерность {GOAL_ONE_DF_LIST_LABELS[num]} : {df.shape}, Отношение к общему {round(len(df)/len(df_full)*100,1)}')
# Out:
# Размерность df_train_job_satisfaction_rate : (4000, 10), Отношение к общему 66.7
# Размерность df_test_features : (2000, 9), Отношение к общему 33.3
# Размерность df_test_target_job_satisfaction_rate : (2000, 2), Отношение к общему 33.3

# %% [markdown]
# Подготовим пайплайн

# %% [markdown]
# В соответствии с [выводами](#duplicates_cell) при обработке дубликатов, следует удалить дубликаты в тренировочной выборке, чтобы улучшить качество модели, а также для снижения риска неожиданного поведения модели.

# %%
X_train = df_train_job_satisfaction_rate.drop(['id'], axis=1)
y_train = df_train_job_satisfaction_rate.drop(['id'], axis=1)

# %%
X_train.drop_duplicates(inplace=True)
y_train.drop_duplicates(inplace=True)

# %%
X_train = X_train.drop(['job_satisfaction_rate'], axis=1)
X_test = df_test_features.drop(['id'], axis=1)
y_train = y_train['job_satisfaction_rate']
y_test = df_test_target_job_satisfaction_rate['job_satisfaction_rate']

# %% [markdown]
# Проверим размерности

# %%
for name, df in {'X_train' : X_train, 'X_test' : X_test, 'y_train' : y_train, 'y_test' : y_test}.items():
    print(f'Размерность датафрейма {name} : {df.shape}')
# Out:
# Размерность датафрейма X_train : (3755, 8)
# Размерность датафрейма X_test : (2000, 8)
# Размерность датафрейма y_train : (3755,)
# Размерность датафрейма y_test : (2000,)

# %% [markdown]
# Подготовим пайплайн

# %%
X_train['dept'].unique().tolist()
# Out:
# ['purchasing', 'sales', 'technology', 'hr', 'marketing', nan]

# %%
#создадим списки количественных, категориальных, ранговых признаков
ohe_columns = ['dept'] 
ord_col = ['workload',
           'level',
           'last_year_promo',
           'last_year_violations',
           'supervisor_evaluation']
num_columns = ['salary', 'employment_years']
 
# Pipeline для кодирования категориальных признаков
ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        
        (
            'ohe', 
            OneHotEncoder(categories=[
                    ['purchasing', 
                     'sales', 
                     'technology', 
                     'hr', 
                     'marketing'
                    ]
            ],
                          drop='first', 
                          min_frequency = 50,
                          handle_unknown='infrequent_if_exist', 
                          sparse_output=False
            )
        )
    ]
)
 
ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        
        (
            'ord',  
            OrdinalEncoder(
                categories=[
                    ['low', 'medium', 'high'],
                    ['junior', 'middle', 'senior'],
                    ['no','yes'],
                    ['yes','no'],
                    [1, 2, 3, 4, 5]
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
) 
 
# Pipeline для подготовки данных
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_col),
        ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)
#
# Из тренировочной выборки были удалены дубликаты при исключении столбца id из выборки
#
# Были выбраны признаки для модели:
#
# - `dept` можно отнести к категориальным данным
# - `level` к ранговым
# - `workload` к ранговым
# - `last_year_promo` к ранговым
# - `last_year_violations` к ранговым
# - `supervisor_evaluation` к ранговым
#
# Также подготовлен pipeline для дальнейшей работы.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Обучение моделей
#
# [К оглавлению](#Оглавление)
#
# Обучите как минимум две модели. Возьмите одну линейную модель, а в качестве второй — дерево решений. Подберите гиперпараметры как минимум для одной модели с помощью одного из известных вам инструментов.
#
#
# Выберите лучшую модель и проверьте её качество. Выбор делайте на основе новой метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»).
#
# Метрика SMAPE вычисляется так:
#
# $\mathrm{SMAPE} = \frac {100} n \sum_{i=1}^n \frac{|y_i - \hat{y_i}|} {(|y_i| + |\hat y_i|) / 2},$
#
# где:
#
# -   $y_i$ — фактическое значение целевого признака для объекта с порядковым номером $i$ в выборке;
# -   $\hat{y_i}$ — предсказанное значение целевого признака для объекта с порядковым номером $i$ в выборке;
# -   $n$ — количество объектов в выборке;
# -   $\sum_{i=1}^n$ — сумма значений, полученная в результате операций, которые следуют за этим знаком, для всех объектов с порядковым номером от $i$ до $n$ в выборке.
#
# Напишите функцию, которая принимает на вход массивы NumPy или объекты `Series` в pandas и возвращает значение метрики SMAPE. Используйте эту метрику при подборе гиперпараметров и оценке качества моделей.
#
# Критерий успеха: SMAPE $≤ 15$ на тестовой выборке.
#
# В решении сохраните работу со всеми моделями, которые вы пробовали. Сделайте выводы.

# %% [markdown]
# Создадим метрику на основе разработанной функции

# %%
smape_scorer = make_scorer(smape_calc, greater_is_better=False)

# %% [markdown]
# Подготовим пайплайн

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
])

param_grid = [
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)], 
        'models__max_depth': range(10, 15),
        'models__max_features': range(20, 25),
        # указываем список методов масштабирования  
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %%
grid = GridSearchCV(
    pipe_final, 
    param_grid=param_grid, 
    cv=5,
    scoring=smape_scorer, 
    n_jobs=-1
)
grid.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid.best_estimator_)
print ('\nМетрика лучшей модели на кросс-валидационной выборке:', -grid.best_score_)

# проверьте работу модели на тестовой выборке
# рассчитайте прогноз на тестовых данных
y_test_pred = grid.best_estimator_.predict(X_test)
print(f'\nМетрика SMAPE на тестовой выборке: {smape_calc(y_test_pred, y_test)}')
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(categories=[['purchasing',
#                                                                                               'sales',
#                                                                                               'technology',
#                                                                                               'hr',
# ...

# %% [markdown]
# Выведем результаты всех моделей и параметров

# %%
res = (
    pd.DataFrame({
        "mean_test_score": -grid.cv_results_["mean_test_score"],
        "mean_fit_time": grid.cv_results_["mean_fit_time"]})
      .join(pd.json_normalize(grid.cv_results_["params"]).add_prefix("param_"))
)

# %%
nice_t(res)
# Out:
# <style  type="text/css" >
#     #T_4bb7f_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_4bb7f_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_4bb7f_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_4bb7f_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %% [markdown]
# Проверим важность признаков при помощи shap

# %%
# preprocessor 
X_encoded = grid.best_estimator_['preprocessor'].fit_transform(X_train)
# применение лучшей модели 
best_model = grid.best_estimator_['models'].fit(X_encoded, y_train)
explainer = shap.PermutationExplainer(best_model, X_encoded)
# построение shap
shap.summary_plot( X_encoded,feature_names=grid.best_estimator_[:-1].get_feature_names_out(), plot_type='bar')

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)
#
# 1. На этапе предобработки из тренировочной выборки были удалены дубликаты при исключении столбца id из выборки
#
# - Были выбраны признаки для модели:
#
#     - `dept` можно отнести к категориальным данным
#     - `level` к ранговым
#     - `workload` к ранговым
#     - `last_year_promo` к ранговым
#     - `last_year_violations` к ранговым
#     - `supervisor_evaluation` к ранговым
#
# 2. Обучено две модели: `DecisionTreeRegressor()`, `LinearRegression()`. Для каждой из них подобраны гиперпараметры. Разработана собственная функция для расчета SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение») и применена для вычисления метрики на кросс-валидации и итогового тестирования модели. На тестовой выборке удалось добиться значения метрики 14.7, что соответствует техническому заданию заказчика.
#
# 3. Выбрана лучшая модель при использовании заданной метрики `DecisionTreeRegressor()`. Применена стратегия:
#
# -   использован один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернул лучшую модель.
#
# 4. OrdinalEncoder может стать проблемой для линейных моделей. Алгоритм может подумать, что между категориями есть логичная математическая связь, хотя в действительности её нет. Однако в этой задаче мы также используем модель дерева решений — для неё это не проблема. Поэтому модель линейной регрессии могла показать плохие результаты.
#
#
# 4. При помощи SHAP была проверена важность признаков:
# - Наибольшее влияние на модель оказывают признаки `employment_years` (стаж) и `supervisor_evaluation` (оценка руководителя)
# - Наименьшее влияние на модель оказывают признаки `last_year_promo` (было ли повышения за последний год) и признаки, связанные с отделом сотрудника

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ## Промежуточный вывод (Цель №1)
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# В рамках работы с `Целью №1` проекта были выполнены следующие задачи:
#
# **Предобработка данных**
#
# **Замена наименований столбцов**
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) замена наименований столбцов не требуется
#
# **Преобразование типов данных:**
#
# - df_train_job_satisfaction_rate
#     - Были заменены типы данных столбца `job_satisfaction_rate`: `object` => `float`
#
# - df_test_features
#     - преобразование типов данных не требуется
#
# - df_test_target_job_satisfaction_rate
#     - Были заменены типы данных столбца `job_satisfaction_rate`: `object` => `float`
#
# **Обработка явных дубликатов**
#
# - Явных дубликатов не обнаружено
#
# - Если не учитывать id, присутствует множество сотрудников с одинаковыми признаками, что может навредить модели. Решение по их удалению примем в соответствующем разделе
#
# Повторяющиеся значения в `df_test_target_job_satisfaction_rate` возможны и допустимы.
#
#
# **Обработка неявных дубликатов, опечаток, ошибок, аномальных значений строковых данных**
#
# **train_job_satisfaction_rate.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
#
# **test_features.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
# - В столбцах `dept` и `workload` обнаружены пропущенные значения ' '. Заменены на np.nan
# - Были обнаружены пропуски в столбце `dept`, `workload`
#
# **test_target_job_satisfaction_rate.csv**
#
# - Столбцы с типом object отсутствуют
#
# **Обработка пропущенных значений**
#
# **Обработка пропущенных значений train_job_satisfaction_rate.csv**
# - В результате исследования было выявлено, что пропущенные значения `df_train_job_satisfaction_rate` могут быть заполнены модой соответствующих столбцов
#
# **Обработка пропущенных значений test_features.csv**
# - В результате исследования было выявлено, что пропущенные значения `df_test_features` могут быть заполнены модой соответствующих столбцов
#
# **Обработка пропущенных значений test_target_job_satisfaction_rate.csv**
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) пропущенных значений не обнаружено
#
# **Предварительная обработка аномальных значений**
#
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) аномальных значений не обнаружено
#
# **Исследовательский анализ**
#
# **Категориальные данные**
#
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`
# - Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
#
# **Количественные данные**
#
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation` и `salary`, но лежат в пределах нормы, их исключение не требуется
#
# **Распределение количественных данных**
#
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.
#
#
# Гистограмма плотности распределения между тренировочной и тестовой выборками показала сходство.
#
# **Корреляционный анализ**
#
# Корреляционный анализ признаков показал, что наибольшее связь между целевым признаком `job_satisfaction_rate` и оценкой руководителя `supervisor_evaluation` - 0.76 и `last_year_violations` - 0.56, остальные признаки имеют невысокие значения. Мультиколлинеарности не обнаружено
#
# **Обучение моделей**
#
# 1. На этапе предобработки из тренировочной выборки были удалены дубликаты при исключении столбца id из выборки
#
# - Были выбраны признаки для модели:
#
#     - `dept` можно отнести к категориальным данным
#     - `level` к ранговым
#     - `workload` к ранговым
#     - `last_year_promo` к ранговым
#     - `last_year_violations` к ранговым
#     - `supervisor_evaluation` к ранговым
#
# 2. Обучено две модели: `DecisionTreeRegressor()`, `LinearRegression()`. Для каждой из них подобраны гиперпараметры. Разработана собственная функция для расчета SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение») и применена для вычисления метрики на кросс-валидации и итогового тестирования модели. На тестовой выборке удалось добиться значения метрики 14.7, что соответствует техническому заданию заказчика.
#
# 3. Выбрана лучшая модель при использовании заданной метрики `DecisionTreeRegressor()`. Применена стратегия:
#
# -   использован один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернул лучшую модель.
#
# 4. OrdinalEncoder может стать проблемой для линейных моделей. Алгоритм может подумать, что между категориями есть логичная математическая связь, хотя в действительности её нет. Однако в этой задаче мы также используем модель дерева решений — для неё это не проблема. Поэтому модель линейной регрессии могла показать плохие результаты.
#
#
# 4. При помощи SHAP была проверена важность признаков:
# - Наибольшее влияние на модель оказывают признаки `employment_years` (стаж) и `supervisor_evaluation` (оценка руководителя)
# - Наименьшее влияние на модель оказывают признаки `last_year_promo` (было ли повышения за последний год) и признаки, связанные с отделом сотрудника

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ## Цель №2: Предсказание увольнения сотрудника из компании
#
# [К оглавлению](#Оглавление)
#
# Для этой задачи вы можете использовать те же входные признаки, что и в предыдущей задаче.
# Однако целевой признак отличается: это quit — увольнение сотрудника из компании.

# %% [markdown]
# ### Общая информация о данных
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Описание данных train_quit.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# -   `id` — уникальный идентификатор сотрудника;
# -   `dept` — отдел, в котором работает сотрудник;
# -   `level` — уровень занимаемой должности;
# -   `workload` — уровень загруженности сотрудника;
# -   `employment_years` — длительность работы в компании (в годах);
# -   `last_year_promo` — показывает, было ли повышение за последний год;
# -   `last_year_violations` — показывает, нарушал ли сотрудник трудовой договор за последний год;
# -   `supervisor_evaluation` — оценка качества работы сотрудника, которую дал руководитель;
# -   `salary` — ежемесячная зарплата сотрудника;
# -   `quit` — уволился ли сотрудник

# %% [markdown]
# #### Общие сведения train_quit.csv
#
# [К оглавлению](#Оглавление)

# %%
data_info(df_train_quit, 15, 5)
# Out:
# Общая информация о датафрейме .head()
# <style  type="text/css" >
#     #T_1364d_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_1364d_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_1364d_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_1364d_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Пропусков не обнаружено
#
# **Тип данных и аномальные значения:**
#
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 1.   dept                   `object` : тип данных соответствует.
# 2.   level                  `object` : тип данных соответствует.
# 3.   workload               `object` : тип данных соответствует.
# 4.   employment_years       `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 5.   last_year_promo        `object` : тип данных соответствует.
# 6.   last_year_violations   `object` : тип данных соответствует.
# 7.   supervisor_evaluation  `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 8.   salary                 `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Значений выше 60000 относительно мало.
# 9.   quit  `object` : тип данных соответствует.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Описание данных test_features.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Входные признаки тестовой выборки те же, что и в прошлой цели
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Описание данных test_target_quit.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# -   `id` — уникальный идентификатор сотрудника;
# -   `quit` — уволился ли сотрудник

# %% [markdown]
# #### Общие сведения test_target_quit.csv
#
# [К оглавлению](#Оглавление)

# %%
data_info(df_test_target_quit, 5, 5)
# Out:
# Общая информация о датафрейме .head()
# <style  type="text/css" >
#     #T_08145_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_08145_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_08145_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_08145_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
#     }</style><table id="T_08145_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >quit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_08145_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_08145_row0_col0" class="data row0 col0" >999029</td>
# ...

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Пропусков не обнаружено
#
# **Тип данных и аномальные значения:**
#
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 1.   quit  `object` : тип данных соответствует.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# <a id='chapter_7_1_conlusion'></a>

# %% [markdown]
# **test_target_quit.csv**
#
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Пропусков не обнаружено
#
# **Тип данных и аномальные значения:**
#
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 1.   dept                   `object` : тип данных соответствует.
# 2.   level                  `object` : тип данных соответствует.
# 3.   workload               `object` : тип данных соответствует.
# 4.   employment_years       `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 5.   last_year_promo        `object` : тип данных соответствует.
# 6.   last_year_violations   `object` : тип данных соответствует.
# 7.   supervisor_evaluation  `int64 ` : тип данных соответствует. Аномальных значений не обнаружено.
# 8.   salary                 `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Значений выше 60000 относительно мало.
# 9.   quit  `object` : тип данных соответствует.
#
# **test_target_quit.csv**
#
# **Наименования столбцов:**
# - Наименования корректны, замены наименований не требуется.
#
# **Пропуски данных:**
# - Пропусков не обнаружено
#
# **Тип данных и аномальные значения:**
#
# 0.   id                     `int64 ` : тип данных соответствует. Аномальных значений не обнаружено. Распределение неравномерное, возможно, id были выбраны в случайном порядке.
# 1.   quit  `object` : тип данных соответствует.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Предобработка данных
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Замена наименований столбцов
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) замена наименований столбцов не требуется

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Обработка пропущенных значений
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) пропусков не обнаружено

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Преобразование типов данных
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) преобразование типов данных не требуется

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Обработка явных дубликатов
#
# [К оглавлению](#Оглавление)

# %%
find_duplicates(GOAL_TWO_DF_LIST, GOAL_TWO_DF_LIST_LABELS)
# Out:
# Количество дубликатов в датафрейме
#  df_train_quit :  0
#
# Количество дубликатов в датафрейме
#  df_test_features :  0
#
# Количество дубликатов в датафрейме
#  df_test_target_quit :  0

# %%
find_duplicates([df_train_quit['id'], 
                 df_test_features['id'], 
                 df_test_target_quit['id']], 
                 GOAL_TWO_DF_LIST_LABELS)
# Out:
# Количество дубликатов в датафрейме
#  df_train_quit :  0
#
# Количество дубликатов в датафрейме
#  df_test_features :  0
#
# Количество дубликатов в датафрейме
#  df_test_target_quit :  0

# %% [markdown]
# <a id='duplicates_cell'></a>

# %%
find_duplicates([df_train_quit.loc[:, df_train_quit.columns !='id'], 
                 df_test_features.loc[:, df_test_features.columns !='id'], 
                 df_test_target_quit.loc[:, df_test_target_quit.columns !='id']], 
                 GOAL_TWO_DF_LIST_LABELS)
# Out:
# Количество дубликатов в датафрейме
#  df_train_quit :  1413
#
# Количество дубликатов в датафрейме
#  df_test_features :  557
#
# Количество дубликатов в датафрейме
#  df_test_target_quit :  1998

# %% [markdown]
# <a id='duplicates_cell_2'></a>

# %% [markdown]
# Как видно, в тренировочной выборке, если не учитывать id, присутствует множество сотрудников с одинаковыми признаками, что может навредить модели. Решение по их удалению примем в соответствующем разделе.

# %% [markdown]
# Проверим, не имеется ли дубликатов в объединенных тестовой и тренировочной выборках

# %%
df_test_2_merged = df_test_features.merge(df_test_target_quit, on='id')

# %%
nice_t(df_test_2_merged.head())
# Out:
# <style  type="text/css" >
#     #T_d30a7_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_d30a7_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_d30a7_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_d30a7_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %%
df_full_2 = pd.concat([
    df_train_quit,
    df_test_2_merged
])

# %%
print(f'\nКоличество дубликатов в датафрейме df_full : \n', df_full_2.duplicated().sum())
# Out:
# Количество дубликатов в датафрейме df_full :
#  0

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Обработка явных дубликатов**
#
# Явных дубликатов не обнаружено. В тренировочной выборке, если не учитывать id, присутствует множество сотрудников с одинаковыми признаками, что может навредить модели. Решение по их удалению примем в соответствующем разделе.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Обработка неявных дубликатов
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### train_quit.csv

# %%
for col in df_train_quit.select_dtypes(include='object'):
    print('\nНаименование столбца: ',col)
    print(df_train_quit[col].unique())
# Out:
# Наименование столбца:  dept
# ['sales' 'purchasing' 'marketing' 'technology' 'hr']
#
# Наименование столбца:  level
# ['middle' 'junior' 'sinior']
#
# Наименование столбца:  workload
# ['high' 'medium' 'low']
#
# Наименование столбца:  last_year_promo
# ['no' 'yes']
#
# Наименование столбца:  last_year_violations
# ['no' 'yes']
#
# Наименование столбца:  quit
# ['no' 'yes']

# %% [markdown]
# В столбце level обнаружена опечатка/ошибка в слове `sinior`, исправим её.

# %%
df_train_quit.replace({'sinior': 'senior'},inplace=True)

# %%
for col in df_train_quit.select_dtypes(include='object'):
    print('\nНаименование столбца: ',col)
    print(df_train_quit[col].unique())
# Out:
# Наименование столбца:  dept
# ['sales' 'purchasing' 'marketing' 'technology' 'hr']
#
# Наименование столбца:  level
# ['middle' 'junior' 'senior']
#
# Наименование столбца:  workload
# ['high' 'medium' 'low']
#
# Наименование столбца:  last_year_promo
# ['no' 'yes']
#
# Наименование столбца:  last_year_violations
# ['no' 'yes']
#
# Наименование столбца:  quit
# ['no' 'yes']

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
# **test_features.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`

# %% [markdown]
# ##### test_features.csv

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
# Входные признаки тестовой выборки те же, что и в прошлой задаче

# %% [markdown]
# ##### test_target_quit.csv

# %%
for col in df_test_target_quit.select_dtypes(include='object'):
    print('\nНаименование столбца: ',col)
    print(df_test_target_quit[col].unique())
# Out:
# Наименование столбца:  quit
# ['yes' 'no']

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
# Неявных дубликатов, ошибок не обнаружено

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **train_quit.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
#
# **test_features.csv**
#
# - Входные признаки тестовой выборки те же, что и в прошлой задаче
#
# **test_target_job_satisfaction_rate.csv**
#
# - Неявных дубликатов, ошибок не обнаружено

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Предварительная обработка аномальных значений
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ##### Выводы раздела
#
# [К оглавлению](#Оглавление)
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) аномальных значений не обнаружено

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Была произведена предобработка данных. Основные детали представлены ниже:
#
# **Замена наименований столбцов**
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) замена наименований столбцов не требуется
#
# **Обработка пропущенных значений**
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) пропусков не обнаружено
#
# **Преобразование типов данных**
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) преобразование типов данных не требуется
#
# **Обработка явных дубликатов**
#
# Явных дубликатов не обнаружено. В тренировочной выборке, если не учитывать id, присутствует множество сотрудников с одинаковыми признаками, что может навредить модели. Решение по их удалению примем в соответствующем разделе.
#
# **Неявные дубликаты**
#
# **train_quit.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
#
# **test_features.csv**
#
# - Входные признаки тестовой выборки те же, что и в прошлой задаче
#
# **test_target_job_satisfaction_rate.csv**
#
# - Неявных дубликатов, ошибок не обнаружено
#
# **Аномальные значения**
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) аномальных значений не обнаружено

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Исследовательский анализ данных
#
# [К оглавлению](#Оглавление)
#
# 1. Проведите исследовательский анализ данных.
# 2. Составьте портрет «уволившегося сотрудника». Например, можно узнать, в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Также можно сравнить среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании.
# 3. Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Проверьте это утверждение: визуализируйте и сравните распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используйте данные с обоими целевыми признаками тестовой выборки.

# %% [markdown]
# #### train_quit.csv
#
# [К оглавлению](#Оглавление)

# %%
data_category_analyze(df_train_quit, ' ', DF_TRAIN_QUIT_X_LABELS)
# Out:
# Не обнаружено столбцов для исключения

# %% [markdown]
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`: Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
# - Большинство сотрудников не планирует увольняться

# %% [markdown]
# ##### Количественные данные

# %%
data_numbers_analyze(df_train_quit, 
                     ['id'], 
                     DF_TRAIN_QUIT_X_LABELS, 
                     DF_TRAIN_QUIT_Y_LABELS, 
                     15, 
                     7)
# Out:
# Исследование числовых значений
#
#
# Общая информация о данных (describe)
# <style  type="text/css" >
#     #T_6f7e0_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_6f7e0_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_6f7e0_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_6f7e0_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
#     }</style><table id="T_6f7e0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >employment_years</th>        <th class="col_heading level0 col1" >supervisor_evaluation</th>        <th class="col_heading level0 col2" >salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6f7e0_level0_row0" class="row_heading level0 row0" >count</th>
# ...

# %% [markdown]
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation` и `salary`, но лежат в пределах нормы

# %% [markdown]
# ##### Распределение количественных данных

# %%
data_hist_analyze(df_train_quit, 
                  ['id'],
                  DF_TRAIN_QUIT_X_LABELS,
                  DF_TRAIN_QUIT_Y_LABELS)
# Out:
# stat=0.886, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)
# stat=0.883, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)
# stat=0.930, p=0.000
#
# Вероятно, распределение не нормальное (не Гауссово)

# %% [markdown]
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Категориальные данные**
#
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`: Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
# - Большинство сотрудников не планирует увольняться
#
# **Количественные данные**
#
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation` и `salary`, но лежат в пределах нормы
#
# **Распределение количественных данных**
#
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### test_features.csv
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)
#
# Входные признаки тестовой выборки те же, что и в прошлой задаче

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### test_target_quit.csv
#
# [К оглавлению](#Оглавление)

# %%
data_category_analyze(df_test_target_quit, ' ', DF_TEST_TARGET_QUIT_X_LABELS)
# Out:
# Не обнаружено столбцов для исключения

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Распределение в тренировочной выборке соответствует тестовой

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ##### Распределение тренировочной и тестовой выборок

# %% [markdown]
# Объединим данные на гистограмме для проверки распределения между тренировочной и тестовой выборками

# %%
hist_comparison(df_train_quit, 
                df_test_2_merged,
                ['id'], 
                ['id'], 
                DF_TRAIN_QUIT_X_LABELS, 
                DF_TRAIN_QUIT_Y_LABELS)

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Как видно из гистограмм, плотность распределения между тренировочной и тестовой выборками похожа.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ##### Портрет уволившегося сотрудника
#
# Составьте портрет «уволившегося сотрудника». Например, можно узнать, в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Также можно сравнить среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании.

# %%
data_category_analyze(df_train_quit.query('quit == "yes"')
                      , ' ',
                      DF_TRAIN_QUIT_X_LABELS)
# Out:
# Не обнаружено столбцов для исключения

# %% [markdown]
# Как показывают диаграммы, уволившиеся сотрудники 99,9% не получали повышение заработной платы за последний год, в основном имеют квалификацию `junior`, из отдела продаж (sales), не нарушали трудового договора, имеют среднюю и низкую рабочую нагрузку

# %% [markdown]
# Сравним среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании.

# %%
df_train_quit.query('quit == "no"')['salary'].median() - df_train_quit.query('quit == "yes"')['salary'].median()
# Out:
# 12000.0

# %% [markdown]
# Разница медианной зарплаты "оставшихся" сотрудников больше чем ушедших на 12000.

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Как показывают диаграммы, уволившиеся сотрудники 99,9% не получали повышение заработной платы за последний год, в основном имеют квалификацию junior, из отдела продаж (sales), не нарушали трудового договора, имеют среднюю и низкую рабочую нагрузку. Разница медианной зарплаты "оставшихся" сотрудников больше чем ушедших на 12000.
#
# Таким образом, можно сделать косвенный вывод о том, что молодые специалисты не получают в организации продвижения (и увеличения заработной платы), поэтому покидают её.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# ##### Распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников.
#
#  Аналитики утверждают, что уровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник. Проверьте это утверждение: визуализируйте и сравните распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Используйте данные с обоими целевыми признаками тестовой выборки.

# %%
nice_t(df_test_2_merged.head())
# Out:
# <style  type="text/css" >
#     #T_82bd2_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_82bd2_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_82bd2_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_82bd2_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %%
df_test_2_merged = df_test_2_merged.merge(df_test_target_job_satisfaction_rate, on='id')

# %%
nice_t(df_test_2_merged.head())
# Out:
# <style  type="text/css" >
#     #T_5b514_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_5b514_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_5b514_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_5b514_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %%
histplot = sns.histplot(data=df_test_2_merged, 
                        x='job_satisfaction_rate',
                        kde='true',
                        hue='quit',
                        alpha = 0.75,
                        bins=100)
histplot.axes.set_title(f'Гистограмма распределения удовлетворенности уволившихся/неуволившихся сотрудников')
histplot.set_xlabel('Коэффициент удовлетворенности')
histplot.set_ylabel('Кол-во', fontsize=10)
plt.show()

# %%
df_test_2_merged.query('quit == "yes"')['job_satisfaction_rate'].describe()
# Out:
# count    564.000000
# mean       0.387713
# std        0.185784
# min        0.040000
# 25%        0.240000
# 50%        0.370000
# 75%        0.492500
# max        0.970000
# Name: job_satisfaction_rate, dtype: float64

# %%
df_test_2_merged.query('quit == "no"')['job_satisfaction_rate'].describe()
# Out:
# count    1436.000000
# mean        0.612040
# std         0.199367
# min         0.030000
# 25%         0.500000
# 50%         0.660000
# 75%         0.760000
# max         1.000000
# Name: job_satisfaction_rate, dtype: float64

# %%
boxplot = sns.boxplot(data=df_test_2_merged, 
                        x='job_satisfaction_rate',
                        y = 'quit'
                      )
boxplot.axes.set_title(f'Диаграммы размаха коэффициента удовлетворенности уволившихся/неуволившихся сотрудников')
boxplot.set_xlabel('Коэффициент удовлетворенности')
boxplot.set_ylabel('Категория', fontsize=10)
plt.show()

# %% [markdown]
# Проверим гипотезу о том,выше ли удовлетворенность не уволившихся сотрудников, чем уволившихся
#
# **Определим две гипотезы.**
# - H<sub>0</sub>: `df_test_2_merged.query('quit == "yes"')` = `df_test_2_merged.query('quit == "no"')`
# - H<sub>1</sub>: `df_test_2_merged.query('quit == "yes"')` < `df_test_2_merged.query('quit == "no"')`
#
# Где:
# - `df_test_2_merged.query('quit == "no"')` - удовлетворенность работой не уволившихся сотрудников
# - `df_test_2_merged.query('quit == "yes"')` - удовлетворенность работой уволившихся сотрудников

# %%
quit_group = df_test_2_merged.query('quit == "yes"')['job_satisfaction_rate']
no_quit_group = df_test_2_merged.query('quit == "no"')['job_satisfaction_rate']

alpha = 0.05 # уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу

# проводим ttest для двух выборок, в качестве альтернативной используем одностороннюю гипотезу «больше»
results = st.ttest_ind(no_quit_group, quit_group, alternative='greater')

print(f'p-value: {results.pvalue}')

# проверяем p-value
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Нет оснований отвергнуть нулевую гипотезу')
# Out:
# p-value: 6.155610332585965e-105
# Отвергаем нулевую гипотезу

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Гистограмма показывает, что сотрудники, которые уволились, обладают меньшим коэффициентом удовлетворенности работой, поэтому это может является причиной увольнения.

# %% [markdown]
# <span style='color:red'>---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# **Категориальные данные**
#
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`: Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
# - Большинство сотрудников не планирует увольняться
#
# **Количественные данные**
#
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation` и `salary`, но лежат в пределах нормы
#
# **Распределение количественных данных**
#
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.
#
# Плотность распределения между тренировочной и тестовой выборками похожа.
#
# **Портрет уволившегося сотрудника**
#
# Как показывают диаграммы, уволившиеся сотрудники 99,9% не получали повышение заработной платы за последний год, в основном имеют квалификацию junior, из отдела продаж (sales), не нарушали трудового договора, имеют среднюю и низкую рабочую нагрузку. Разница медианной зарплаты "оставшихся" сотрудников больше чем ушедших на 12000.
#
# Таким образом, можно сделать косвенный вывод о том, что молодые специалисты не получают в организации продвижения (и увеличения заработной платы), поэтому покидают её.
#
# Гистограмма показывает, что сотрудники, которые уволились, обладают примерно меньшим коэффициентом удовлетворенности работой, поэтому это может является причиной увольнения.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Добавление нового входного признака
#
# [К оглавлению](#Оглавление)
#
# Допустим, `job_satisfaction_rate` и `quit` действительно связаны и вы получили необходимое значение метрики в первой задаче. Тогда добавьте `job_satisfaction_rate`, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.

# %%
df_train_2_merged = df_train_quit.copy()

# %%
job_sat_pred = grid.best_estimator_.predict(df_train_2_merged.loc[:, 'dept':'salary'])

# %%
df_train_2_merged['job_satisfaction_rate'] = np.array(job_sat_pred)

# %%
df_train_2_merged['job_satisfaction_rate'] = round(df_train_2_merged['job_satisfaction_rate'],2)

# %%
nice_t(df_train_2_merged.head())
# Out:
# <style  type="text/css" >
#     #T_1565b_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_1565b_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_1565b_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_1565b_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
# ...

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Был добавлен новый признак `job_satisfaction_rate`, спрогнозированный на основе ранее полученной модели к входным признакам второй цели.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Корреляционный анализ признаков
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Проверим связь признаков в тренировочной выборке

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df_train_2_merged 
            .loc[:,'dept':'job_satisfaction_rate']
            .phik_matrix(verbose=False, interval_cols=interval_cols)
            , annot=True, 
            fmt='.2f'
            )
plt.show()

# %% [markdown]
# ###### Выводы подраздела
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# Матрица показала, что наибольшая связь между признаками `quit` и `employment_years`,  на втором месте с `salary` и `job_satisfaction_rate`.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Подготовка данных
#
# [К оглавлению](#Оглавление)
#
# Подготовьте признаки так же, как и в первой задаче: выполните подготовку в пайплайне, дополнив пайплайн предобработки. При кодировании учитывайте особенности признаков и моделей и используйте как минимум два кодировщика.

# %% [markdown]
# Создадим новые датафреймы и отсортируем по id

# %%
X_train_2 = df_train_2_merged.sort_values(by='id')
X_test_2 = df_test_2_merged.sort_values(by='id')
y_train_2 = df_train_2_merged.sort_values(by='id')
y_test_2 = df_test_2_merged.sort_values(by='id')

# %% [markdown]
# Исключим столбцы

# %%
X_train_2 = X_train_2.drop(['id', 'quit'], axis=1)
X_test_2 = X_test_2.drop(['id', 'quit'], axis=1)
y_train_2 = y_train_2['quit']
y_test_2 = y_test_2['quit']

# %% [markdown]
# Проверим размеры

# %%
for name, df in {'X_train_2' : X_train_2, 
                 'X_test_2' : X_test_2, 
                 'y_train_2' : y_train_2, 
                 'y_test_2' : y_test_2}.items():
    print(f'Размерность датафрейма {name} : {df.shape}')
# Out:
# Размерность датафрейма X_train_2 : (4000, 9)
# Размерность датафрейма X_test_2 : (2000, 9)
# Размерность датафрейма y_train_2 : (4000,)
# Размерность датафрейма y_test_2 : (2000,)

# %% [markdown]
# Подготовим пайплайн

# %%
#создадим списки количественных, категориальных, ранговых признаков
ohe_columns_2 = ['dept'] 
ord_col_2 = ['workload',
           'level',
           'last_year_promo',
           'last_year_violations',
           'supervisor_evaluation']
num_columns_2 = ['salary', 'employment_years', 'job_satisfaction_rate']
 
# Pipeline для кодирования категориальных признаков
ohe_pipe_2 = Pipeline(
    [
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(categories=[
                    ['purchasing', 
                     'sales', 
                     'technology', 
                     'hr', 
                     'marketing'
                    ]
            ],
                          drop='first', 
                          min_frequency = 50,
                          handle_unknown='infrequent_if_exist', 
                          sparse_output=False
            )
        )
    ]
)
 
ord_pipe_2 = Pipeline(
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',  
            OrdinalEncoder(
                categories=[
                    ['low', 'medium', 'high'],
                    ['junior', 'middle', 'senior'],
                    ['no','yes'],
                    ['yes','no'],
                    [1, 2, 3, 4, 5]
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
) 
 
# Pipeline для подготовки данных
data_preprocessor_2 = ColumnTransformer(
    [
        ('ohe', ohe_pipe_2, ohe_columns_2),
        ('ord', ord_pipe_2, ord_col_2),
        ('num', MinMaxScaler(), num_columns_2)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)
#
# Были выбраны признаки для модели:
#
# - `dept` можно отнести к категориальным данным
# - `level` к ранговым
# - `workload` к ранговым
# - `last_year_promo` к ранговым
# - `last_year_violations` к ранговым
# - `supervisor_evaluation` к ранговым
#
# Также подготовлен pipeline для дальнейшей работы.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ### Обучение моделей
#
# [К оглавлению](#Оглавление)
#
# Обучите как минимум три модели. Как минимум для двух из них подберите гиперпараметры. Проверьте качество лучшей модели.
#
# Метрика оценки качества в этой задаче — ROC-AUC. Критерий успеха: ROC-AUC $≥ 0.91$ на тестовой выборке. Напомним: отбор признаков часто помогает улучшить метрику.

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final_2 = Pipeline([
    ('preprocessor', data_preprocessor_2),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])
 
param_grid_2 = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2,5),
        # указываем список методов масштабирования  
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]
 
randomized_search_2 = RandomizedSearchCV(
    pipe_final_2, 
    param_grid_2, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search_2.fit(X_train_2, y_train_2)

print('Лучшая модель и её параметры:\n\n', randomized_search_2.best_estimator_)
print ('\nМетрика лучшей модели на кросс-валидационной выборке:', randomized_search_2.best_score_)

# проверьте работу модели на тестовой выборке
# рассчитайте прогноз на тестовых данных
y_test_pred_2 = randomized_search_2.best_estimator_.predict_proba(X_test_2)[:,1]
print(f'\nМетрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test_2, y_test_pred_2)}')
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(categories=[['purchasing',
#                                                                                               'sales',
#                                                                                               'technology',
#                                                                                               'hr',
# ...

# %%
results = pd.DataFrame(randomized_search_2.cv_results_)

# %%
nice_t(results.loc[:, ['param_models', 'mean_test_score','rank_test_score']].sort_values(by='rank_test_score'))
# Out:
# <style  type="text/css" >
#     #T_4ddb9_ th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: #40E0D0;
#     }    #T_4ddb9_ td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_4ddb9_ tr:nth-child(even) {
#           background-color: #CFECEC;
#     }    #T_4ddb9_ tr:hover {
#           background-color: #40E0D0;
#           text-align: center;
#     }</style><table id="T_4ddb9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >param_models</th>        <th class="col_heading level0 col1" >mean_test_score</th>        <th class="col_heading level0 col2" >rank_test_score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ddb9_level0_row0" class="row_heading level0 row0" >3</th>
# ...

# %%
# выведем на экран ROC-кривую методом from_estimator()
RocCurveDisplay.from_estimator(randomized_search_2, X_test_2, y_test_2)
plt.plot([0,1], [0,1], linestyle='dashed', label='Random prediction')
plt.title("График ROC-AUC")
plt.legend()
plt.show()
# Out:
# Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros

# %% [markdown]
# #### Выводы главы
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# В данном случае, наилучшей моделью оказалась SVC, но некоторые другие модели имеют близкие значения (LogisticRegression, KNeighborsClassifier) . Модель SVC меньше подвержена влиянию выбросов, так как в качестве разделяющих векторов использует крайние к гиперплоскости наблюдения,  используется для задач и классификации, и регрессии, основана на геометрическом подходе: расстояния до гиперплоскости.

# %% [markdown]
# <span style='color:blue'> +-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+ </span>

# %% [markdown]
# ## Общий вывод
#
# [К оглавлению](#Оглавление)

# %% [markdown]
# В рамках работы над проектом были достигнуты следующие цели:
# 1. Построена модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
#
# 2. Построена модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# В рамках работы с `Целью №1` проекта были выполнены следующие задачи:
#
# **Предобработка данных**
#
# **Замена наименований столбцов**
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) замена наименований столбцов не требуется
#
# **Преобразование типов данных:**
#
# - df_train_job_satisfaction_rate
#     - Были заменены типы данных столбца `job_satisfaction_rate`: `object` => `float`
#
# - df_test_features
#     - преобразование типов данных не требуется
#
# - df_test_target_job_satisfaction_rate
#     - Были заменены типы данных столбца `job_satisfaction_rate`: `object` => `float`
#
# **Обработка явных дубликатов**
#
# - Явных дубликатов не обнаружено
#
# - Если не учитывать id, присутствует множество сотрудников с одинаковыми признаками, что может навредить модели. Решение по их удалению примем в соответствующем разделе
#
# Повторяющиеся значения в `df_test_target_job_satisfaction_rate` возможны и допустимы.
#
#
# **Обработка неявных дубликатов, опечаток, ошибок, аномальных значений строковых данных**
#
# **train_job_satisfaction_rate.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
#
# **test_features.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
# - В столбцах `dept` и `workload` обнаружены пропущенные значения ' '. Заменены на np.nan
# - Были обнаружены пропуски в столбце `dept`, `workload`
#
# **test_target_job_satisfaction_rate.csv**
#
# - Столбцы с типом object отсутствуют
#
# **Обработка пропущенных значений**
#
# **Обработка пропущенных значений train_job_satisfaction_rate.csv**
# - В результате исследования было выявлено, что пропущенные значения `df_train_job_satisfaction_rate` могут быть заполнены модой соответствующих столбцов
#
# **Обработка пропущенных значений test_features.csv**
# - В результате исследования было выявлено, что пропущенные значения `df_test_features` могут быть заполнены модой соответствующих столбцов
#
# **Обработка пропущенных значений test_target_job_satisfaction_rate.csv**
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) пропущенных значений не обнаружено
#
# **Предварительная обработка аномальных значений**
#
# - В соответствии с [выводами главы 5.1](#chapter_one_conlusion) аномальных значений не обнаружено
#
# **Исследовательский анализ**
#
# **Категориальные данные**
#
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`
# - Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
#
# **Количественные данные**
#
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation` и `salary`, но лежат в пределах нормы, их исключение не требуется
#
# **Распределение количественных данных**
#
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.
#
#
# Гистограмма плотности распределения между тренировочной и тестовой выборками показала сходство.
#
# **Корреляционный анализ**
#
# Корреляционный анализ признаков показал, что наибольшее связь между целевым признаком `job_satisfaction_rate` и оценкой руководителя `supervisor_evaluation` - 0.76 и `last_year_violations` - 0.56, остальные признаки имеют невысокие значения. Мультиколлинеарности не обнаружено
#
# **Обучение моделей**
#
# 1. На этапе предобработки из тренировочной выборки были удалены дубликаты при исключении столбца id из выборки
#
# - Были выбраны признаки для модели:
#
#     - `dept` можно отнести к категориальным данным
#     - `level` к ранговым
#     - `workload` к ранговым
#     - `last_year_promo` к ранговым
#     - `last_year_violations` к ранговым
#     - `supervisor_evaluation` к ранговым
#
# 2. Обучено две модели: `DecisionTreeRegressor()`, `LinearRegression()`. Для каждой из них подобраны гиперпараметры. Разработана собственная функция для расчета SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение») и применена для вычисления метрики на кросс-валидации и итогового тестирования модели. На тестовой выборке удалось добиться значения метрики 14.7, что соответствует техническому заданию заказчика.
#
# 3. Выбрана лучшая модель при использовании заданной метрики `DecisionTreeRegressor()`. Применена стратегия:
#
# -   использован один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернул лучшую модель.
#
# 4. OrdinalEncoder может стать проблемой для линейных моделей. Алгоритм может подумать, что между категориями есть логичная математическая связь, хотя в действительности её нет. Однако в этой задаче мы также используем модель дерева решений — для неё это не проблема. Поэтому модель линейной регрессии могла показать плохие результаты.
#
#
# 4. При помощи SHAP была проверена важность признаков:
# - Наибольшее влияние на модель оказывают признаки `employment_years` (стаж) и `supervisor_evaluation` (оценка руководителя)
# - Наименьшее влияние на модель оказывают признаки `last_year_promo` (было ли повышения за последний год) и признаки, связанные с отделом сотрудника
#
#
#
#
#
# В рамках работы с `Целью №2` проекта были выполнены следующие задачи:
#
# **Предобработка данных цели №2**
#
# Была произведена предобработка данных. Основные детали представлены ниже:
#
# **Замена наименований столбцов**
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) замена наименований столбцов не требуется
#
# **Обработка пропущенных значений**
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) пропусков не обнаружено
#
# **Преобразование типов данных**
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) преобразование типов данных не требуется
#
# **Обработка явных дубликатов**
#
# Явных дубликатов не обнаружено. В тренировочной выборке, если не учитывать id, присутствует множество сотрудников с одинаковыми признаками, что может навредить модели. Решение по их удалению примем в соответствующем разделе.
#
# **Неявные дубликаты**
#
# **train_quit.csv**
#
# - В столбце level обнаружена опечатка/ошибка в слове `sinior`, и исправлена на `senior`
#
# **test_features.csv**
#
# - Входные признаки тестовой выборки те же, что и в прошлой задаче
#
# **test_target_job_satisfaction_rate.csv**
#
# - Неявных дубликатов, ошибок не обнаружено
#
# **Аномальные значения**
#
# В соответствии с [выводами главы 7.1](#chapter_7_1_conlusion) аномальных значений не обнаружено
#
# **Исследовательский анализ цели №2**
#
# **Категориальные данные**
#
# Как видно из диаграмм, значения распределены неравномерно, особенно в случае со столбцами `last_year_promo` и `last_year_violations`.
#
# Некоторые особенности:
# - Большинство сотрудников из отдела `sales`
# - По количеству `middle` и `junior`: Больше всего сотрудников с рабочей нагрузкой `medium`
# - Практически никто не получил повышения за последний год
# - Количество нарушений на высоком уровне (14%)
# - Большинство сотрудников не планирует увольняться
#
# **Количественные данные**
#
# Аномальных значений в данных не обнаружено, имеются выбросы в признаках `supervisor_evaluation` и `salary`, но лежат в пределах нормы
#
# **Распределение количественных данных**
#
# Как видно из графиков, ни один из признаков не обладает нормальным распределением.
#
# Плотность распределения между тренировочной и тестовой выборками похожа.
#
# **Портрет уволившегося сотрудника**
#
# Как показывают диаграммы, уволившиеся сотрудники 99,9% не получали повышение заработной платы за последний год, в основном имеют квалификацию junior, из отдела продаж (sales), не нарушали трудового договора, имеют среднюю и низкую рабочую нагрузку. Разница медианной зарплаты "оставшихся" сотрудников больше чем ушедших на 12000.
#
# Таким образом, можно сделать косвенный вывод о том, что молодые специалисты не получают в организации продвижения (и увеличения заработной платы), поэтому покидают её.
#
# Гистограмма показывает, что сотрудники, которые уволились, обладают примерно меньшим коэффициентом удовлетворенности работой, поэтому это может является причиной увольнения.
#
# **Обучение моделей для цели №2**
#
# Были выбраны признаки для модели:
#
# - `dept` можно отнести к категориальным данным
# - `level` к ранговым
# - `workload` к ранговым
# - `last_year_promo` к ранговым
# - `last_year_violations` к ранговым
# - `supervisor_evaluation` к ранговым
#
# Также подготовлен pipeline для дальнейшей работы.
#
# В данном случае, наилучшей моделью оказалась SVC, но некоторые другие модели имеют близкие значения (LogisticRegression, KNeighborsClassifier) . Модель SVC меньше подвержена влиянию выбросов, так как в качестве разделяющих векторов использует крайние к гиперплоскости наблюдения,  используется для задач и классификации, и регрессии, основана на геометрическом подходе: расстояния до гиперплоскости.
#
#
#
# **Рекомендации для заказчика**
# - Следует рассмотреть возможности для проведения дополнительного исследования, касающегося улучшения качества модели с увеличенным количеством данных, в особенности, с высокой зарплатой сотрудников, так как в текущей выборке таких данных слишком мало.
# - Исследование показало, что молодые специалисты с низкой зарплатой увольняются чаще. Следует провести дополнительный анализ, который покажет, выгоднее сохранять работников на своих рабочих местах или принять "текучку" кадров. В любом случае, возможность роста для сотрудников внутри компании может послужить мощным стимулом для увеличения производительности труда (у сотрудников появится мотивация лучше выполнять свои трудовые обязанности) и культуры труда в целом.
